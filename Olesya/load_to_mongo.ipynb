# %%
import pymongo
import json 
from pprint import pprint
import pandas as pd
import copy

# %% [markdown]
# ## Prepare data to upload to MongoDB

# %% [markdown]
# ### Top apps by category as single dictionary

# %%
with open('db/top_apps.json') as f:
    data = json.load(f)

pprint(data)
# Out:
# {'children': [{'children': [{'installs': 10000000,
#                              'name': 'Textgram',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 295221},
#                             {'installs': 10000000,
#                              'name': 'ibis Paint X',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 224399},
#                             {'installs': 5000000,
#                              'name': 'FlipaClip',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 194216},
#                             {'installs': 10000000,
#                              'name': 'Canva: Poster, banner, card maker & '
#                                      'graphic design',
#                              'price': 0.0,
#                              'rating': 4.7,
#                              'reviews': 174531},
#                             {'installs': 5000000,
#                              'name': 'U Launcher Lite',
#                              'price': 0.0,
#                              'rating': 4.7,
#                              'reviews': 87510},
#                             {'installs': 10000000,
#                              'name': 'Tattoo Name On My Photo Editor',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 44829},
#                             {'installs': 1000000,
#                              'name': 'Infinite Painter',
#                              'price': 0.0,
#                              'rating': 4.1,
#                              'reviews': 36815},
#                             {'installs': 5000000,
#                              'name': 'Floor Plan Creator',
#                              'price': 0.0,
#                              'rating': 4.1,
#                              'reviews': 36639},
#                             {'installs': 1000000,
#                              'name': 'Text on Photo',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 13880},
#                             {'installs': 50000000,
#                              'name': 'Sketch',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 215644}],
#                'name': 'Art and design'},
#               {'children': [{'installs': 10000000,
#                              'name': 'Android Auto',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 271920},
#                             {'installs': 1000000,
#                              'name': 'Tickets + PDA 2018 Exam',
#                              'price': 0.0,
#                              'rating': 4.9,
#                              'reviews': 197136},
#                             {'installs': 10000000,
#                              'name': 'AutoScout24',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 186648},
#                             {'installs': 5000000,
#                              'name': 'Fines of the State Traffic Safety '
#                                      'Inspectorate are official: inspection, '
#                                      'payment of fines',
#                              'price': 0.0,
#                              'rating': 4.8,
#                              'reviews': 116986},
#                             {'installs': 1000000,
#                              'name': 'Fuelio: Gas log & costs',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 65786},
#                             {'installs': 5000000,
#                              'name': 'Used cars for sale',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 52530},
#                             {'installs': 5000000,
#                              'name': 'Ulysse Speedometer',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 40211},
#                             {'installs': 1000000,
#                              'name': 'ezETC (ETC balance inquiry, meter trial, '
#                                      'real',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 38846},
#                             {'installs': 1000000,
#                              'name': 'auto fines',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 31433},
#                             {'installs': 1000000,
#                              'name': 'CarMax',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 21777}],
#                'name': 'Auto and vehicles'},
#               {'children': [{'installs': 1000000,
#                              'name': 'ipsy: Makeup, Beauty, and Tips',
#                              'price': 0.0,
#                              'rating': 4.9,
#                              'reviews': 49790},
#                             {'installs': 1000000,
#                              'name': 'Ulta Beauty',
#                              'price': 0.0,
#                              'rating': 4.7,
#                              'reviews': 42050},
#                             {'installs': 1000000,
#                              'name': 'Mirror',
#                              'price': 0.0,
#                              'rating': 3.9,
#                              'reviews': 32090},
#                             {'installs': 1000000,
#                              'name': 'Sephora: Skin Care, Beauty Makeup & '
#                                      'Fragrance Shop',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 26834},
#                             {'installs': 1000000,
#                              'name': 'Selfie Camera',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 17934},
#                             {'installs': 1000000,
#                              'name': 'Mirror Camera (Mirror + Selfie Camera)',
#                              'price': 0.0,
#                              'rating': 4.1,
#                              'reviews': 9315},
#                             {'installs': 1000000,
#                              'name': 'Filters for Selfie',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 8572},
#                             {'installs': 1000000,
#                              'name': 'Rainbow Camera',
#                              'price': 0.0,
#                              'rating': 3.7,
#                              'reviews': 3871},
#                             {'installs': 10000000,
#                              'name': 'Beauty Camera',
#                              'price': 0.0,
#                              'rating': 4.0,
#                              'reviews': 113715},
#                             {'installs': 5000000,
#                              'name': 'Best Hairstyles step by step',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 45452}],
#                'name': 'Beauty'},
#               {'children': [{'installs': 100000000,
#                              'name': 'Wattpad 📖 Free Books',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 2914724},
#                             {'installs': 100000000,
#                              'name': 'Bible',
#                              'price': 0.0,
#                              'rating': 4.7,
#                              'reviews': 2440695},
#                             {'installs': 10000000,
#                              'name': 'JW Library',
#                              'price': 0.0,
#                              'rating': 4.9,
#                              'reviews': 922752},
#                             {'installs': 10000000,
#                              'name': 'Dictionary.com: Find Definitions for '
#                                      'English Words',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 899010},
#                             {'installs': 100000000,
#                              'name': 'Amazon Kindle',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 814080},
#                             {'installs': 10000000,
#                              'name': 'Wikipedia',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 577550},
#                             {'installs': 100000000,
#                              'name': 'Audiobooks from Audible',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 568922},
#                             {'installs': 10000000,
#                              'name': 'Quran for Android',
#                              'price': 0.0,
#                              'rating': 4.7,
#                              'reviews': 497826},
#                             {'installs': 10000000,
#                              'name': 'Dictionary',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 454060},
#                             {'installs': 1000000000,
#                              'name': 'Google Play Books',
#                              'price': 0.0,
#                              'rating': 3.9,
#                              'reviews': 1433233}],
#                'name': 'Books and reference'},
#               {'children': [{'installs': 50000000,
#                              'name': 'Facebook Pages Manager',
#                              'price': 0.0,
#                              'rating': 4.0,
#                              'reviews': 1279184},
#                             {'installs': 10000000,
#                              'name': 'Uber Driver',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 1254730},
#                             {'installs': 100000000,
#                              'name': 'OfficeSuite : Free Office + PDF Editor',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 1002861},
#                             {'installs': 50000000,
#                              'name': 'Vault',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 984451},
#                             {'installs': 100000000,
#                              'name': 'File Commander',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 758590},
#                             {'installs': 50000000,
#                              'name': 'Indeed Job Search',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 674730},
#                             {'installs': 10000000,
#                              'name': 'MyASUS',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 380837},
#                             {'installs': 10000000,
#                              'name': 'Tiny Scanner',
#                              'price': 0.0,
#                              'rating': 4.7,
#                              'reviews': 286897},
#                             {'installs': 50000000,
#                              'name': 'Docs To Go™ Free Office Suite',
#                              'price': 0.0,
#                              'rating': 4.1,
#                              'reviews': 217730},
#                             {'installs': 10000000,
#                              'name': 'ES Task Manager (Task Killer )',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 171771}],
#                'name': 'Business'},
#               {'children': [{'installs': 5000000,
#                              'name': "Narrator's Voice",
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 564387},
#                             {'installs': 1000000,
#                              'name': 'Manga Rock',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 238970},
#                             {'installs': 5000000,
#                              'name': 'comico Popular Original Cartoon Updated '
#                                      'Everyday Comico',
#                              'price': 0.0,
#                              'rating': 3.2,
#                              'reviews': 93965},
#                             {'installs': 1000000,
#                              'name': 'GANMA!',
#                              'price': 0.0,
#                              'rating': 4.7,
#                              'reviews': 57106},
#                             {'installs': 5000000,
#                              'name': 'Perfect Viewer',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 51981},
#                             {'installs': 5000000,
#                              'name': 'Comics',
#                              'price': 0.0,
#                              'rating': 4.1,
#                              'reviews': 45651},
#                             {'installs': 1000000,
#                              'name': 'WebComics',
#                              'price': 0.0,
#                              'rating': 4.8,
#                              'reviews': 33783},
#                             {'installs': 1000000,
#                              'name': 'Tapas',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 29839},
#                             {'installs': 1000000,
#                              'name': 'Lezhin Comics',
#                              'price': 0.0,
#                              'rating': 3.0,
#                              'reviews': 28447},
#                             {'installs': 10000000,
#                              'name': 'LINE WEBTOON',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 1013635}],
#                'name': 'Comics'},
#               {'children': [{'installs': 1000000000,
#                              'name': 'WhatsApp Messenger',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 69119316},
#                             {'installs': 1000000000,
#                              'name': 'Messenger',
#                              'price': 0.0,
#                              'rating': 4.0,
#                              'reviews': 56642847},
#                             {'installs': 500000000,
#                              'name': 'UC Browser',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 17712922},
#                             {'installs': 500000000,
#                              'name': 'Viber Messenger',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 11334799},
#                             {'installs': 500000000,
#                              'name': 'LINE: Free Calls & Messages',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 10790289},
#                             {'installs': 1000000000,
#                              'name': 'Skype',
#                              'price': 0.0,
#                              'rating': 4.1,
#                              'reviews': 10484169},
#                             {'installs': 1000000000,
#                              'name': 'Google Chrome: Fast & Secure',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 9642995},
#                             {'installs': 500000000,
#                              'name': 'imo free video calls and chat',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 4785892},
#                             {'installs': 1000000000,
#                              'name': 'Gmail',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 4604324},
#                             {'installs': 1000000000,
#                              'name': 'Hangouts',
#                              'price': 0.0,
#                              'rating': 4.0,
#                              'reviews': 3419249}],
#                'name': 'Communication'},
#               {'children': [{'installs': 10000000,
#                              'name': 'Zoosk Dating App: Meet Singles',
#                              'price': 0.0,
#                              'rating': 4.0,
#                              'reviews': 516801},
#                             {'installs': 10000000,
#                              'name': 'Moco',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 313724},
#                             {'installs': 10000000,
#                              'name': 'Hot or Not',
#                              'price': 0.0,
#                              'rating': 4.1,
#                              'reviews': 305708},
#                             {'installs': 10000000,
#                              'name': 'OkCupid Dating',
#                              'price': 0.0,
#                              'rating': 4.1,
#                              'reviews': 285726},
#                             {'installs': 10000000,
#                              'name': 'Hitwe',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 243950},
#                             {'installs': 10000000,
#                              'name': 'Find Real Love — YouLove Premium Dating',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 212626},
#                             {'installs': 5000000,
#                              'name': 'iPair',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 182986},
#                             {'installs': 5000000,
#                              'name': 'Free Dating App & Flirt Chat',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 172460},
#                             {'installs': 10000000,
#                              'name': 'Chat Rooms, Avatars, Date',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 135418},
#                             {'installs': 10000000,
#                              'name': 'Match™ Dating',
#                              'price': 0.0,
#                              'rating': 3.7,
#                              'reviews': 76646}],
#                'name': 'Dating'},
#               {'children': [{'installs': 10000000,
#                              'name': 'Learn languages, grammar & vocabulary '
#                                      'with Memrise',
#                              'price': 0.0,
#                              'rating': 4.7,
#                              'reviews': 1107903},
#                             {'installs': 10000000,
#                              'name': 'Math Tricks',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 342918},
#                             {'installs': 10000000,
#                              'name': 'Learn English with Wlingua',
#                              'price': 0.0,
#                              'rating': 4.7,
#                              'reviews': 314299},
#                             {'installs': 10000000,
#                              'name': 'Peak',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 272145},
#                             {'installs': 10000000,
#                              'name': 'Babbel',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 266948},
#                             {'installs': 10000000,
#                              'name': 'Lumosity: #1 Brain Games & Cognitive '
#                                      'Training App',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 215301},
#                             {'installs': 10000000,
#                              'name': 'Quizlet: Learn Languages & Vocab with '
#                                      'Flashcards',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 211856},
#                             {'installs': 10000000,
#                              'name': 'busuu: Learn Languages',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 206527},
#                             {'installs': 10000000,
#                              'name': 'Edmodo',
#                              'price': 0.0,
#                              'rating': 4.1,
#                              'reviews': 200058},
#                             {'installs': 100000000,
#                              'name': 'Duolingo: Learn Languages Free',
#                              'price': 0.0,
#                              'rating': 4.7,
#                              'reviews': 6289924}],
#                'name': 'Education'},
#               {'children': [{'installs': 100000000,
#                              'name': 'Netflix',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 5456208},
#                             {'installs': 100000000,
#                              'name': 'Hotstar',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 4885646},
#                             {'installs': 50000000,
#                              'name': 'Twitch: Livestream Multiplayer Games & '
#                                      'Esports',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 2133296},
#                             {'installs': 100000000,
#                              'name': 'Talking Angela',
#                              'price': 0.0,
#                              'rating': 3.7,
#                              'reviews': 1828284},
#                             {'installs': 100000000,
#                              'name': 'Talking Ben the Dog',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 1633682},
#                             {'installs': 50000000,
#                              'name': 'Talking Ginger 2',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 702975},
#                             {'installs': 50000000,
#                              'name': 'PlayStation App',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 613059},
#                             {'installs': 100000000,
#                              'name': 'IMDb Movies & TV',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 501498},
#                             {'installs': 50000000,
#                              'name': 'YouTube Kids',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 470089},
#                             {'installs': 1000000000,
#                              'name': 'Google Play Games',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 7165362}],
#                'name': 'Entertainment'},
#               {'children': [{'installs': 5000000,
#                              'name': 'Ticketmaster Event Tickets',
#                              'price': 0.0,
#                              'rating': 4.0,
#                              'reviews': 40113},
#                             {'installs': 5000000,
#                              'name': 'StubHub',
#                              'price': 0.0,
#                              'rating': 4.0,
#                              'reviews': 26089},
#                             {'installs': 1000000,
#                              'name': 'Fever',
#                              'price': 0.0,
#                              'rating': 4.0,
#                              'reviews': 20611},
#                             {'installs': 1000000,
#                              'name': 'SeatGeek',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 15558},
#                             {'installs': 1000000,
#                              'name': 'Gametime',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 8800},
#                             {'installs': 1000000,
#                              'name': 'Vivid Seats',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 8232},
#                             {'installs': 100000,
#                              'name': 'vide',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 5839},
#                             {'installs': 100000,
#                              'name': 'KudaGo',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 4298},
#                             {'installs': 100000,
#                              'name': 'LBB',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 3874},
#                             {'installs': 500000,
#                              'name': 'Reminder',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 7074}],
#                'name': 'Events'},
#               {'children': [{'installs': 100000000,
#                              'name': 'Hay Day',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 10053186},
#                             {'installs': 50000000,
#                              'name': 'Boom Beach',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 5591653},
#                             {'installs': 50000000,
#                              'name': 'Township',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 4451317},
#                             {'installs': 50000000,
#                              'name': 'SimCity BuildIt',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 4218587},
#                             {'installs': 100000000,
#                              'name': 'Talking Tom Cat 2',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 3213548},
#                             {'installs': 100000000,
#                              'name': 'Bubble Witch 2 Saga',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 2838064},
#                             {'installs': 50000000,
#                              'name': 'MARVEL Future Fight',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 2354042},
#                             {'installs': 100000000,
#                              'name': 'Bitmoji',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 2312084},
#                             {'installs': 50000000,
#                              'name': 'Clash of Kings : The King Of Fighters '
#                                      'version',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 2233681},
#                             {'installs': 100000000,
#                              'name': 'Talking Tom Cat',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 1838090}],
#                'name': 'Family'},
#               {'children': [{'installs': 10000000,
#                              'name': 'Chase Mobile',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 1374549},
#                             {'installs': 10000000,
#                              'name': 'Bank of Brazil',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 1336246},
#                             {'installs': 10000000,
#                              'name': 'Itau bank',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 957973},
#                             {'installs': 10000000,
#                              'name': 'Credit Karma',
#                              'price': 0.0,
#                              'rating': 4.7,
#                              'reviews': 706301},
#                             {'installs': 10000000,
#                              'name': 'Capital One® Mobile',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 510392},
#                             {'installs': 10000000,
#                              'name': 'İşCep',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 381788},
#                             {'installs': 10000000,
#                              'name': 'Bank of America Mobile Banking',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 341090},
#                             {'installs': 10000000,
#                              'name': 'CASHIER',
#                              'price': 0.0,
#                              'rating': 3.3,
#                              'reviews': 335738},
#                             {'installs': 100000000,
#                              'name': 'Google Pay',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 347838},
#                             {'installs': 50000000,
#                              'name': 'PayPal',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 659741}],
#                'name': 'Finance'},
#               {'children': [{'installs': 10000000,
#                              'name': "Domino's Pizza USA",
#                              'price': 0.0,
#                              'rating': 4.7,
#                              'reviews': 1032935},
#                             {'installs': 10000000,
#                              'name': 'Tastely',
#                              'price': 0.0,
#                              'rating': 4.7,
#                              'reviews': 611136},
#                             {'installs': 10000000,
#                              'name': 'Zomato',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 511228},
#                             {'installs': 10000000,
#                              'name': 'Foursquare City Guide',
#                              'price': 0.0,
#                              'rating': 4.1,
#                              'reviews': 483960},
#                             {'installs': 10000000,
#                              'name': 'Starbucks',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 455377},
#                             {'installs': 10000000,
#                              'name': 'Uber Eats: Local Food Delivery',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 333208},
#                             {'installs': 10000000,
#                              'name': 'Pizza Hut',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 321134},
#                             {'installs': 10000000,
#                              'name': 'foodpanda',
#                              'price': 0.0,
#                              'rating': 4.0,
#                              'reviews': 292969},
#                             {'installs': 10000000,
#                              'name': "McDonald's",
#                              'price': 0.0,
#                              'rating': 3.6,
#                              'reviews': 145323},
#                             {'installs': 10000000,
#                              'name': 'Cookpad',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 131569}],
#                'name': 'Food and drink'},
#               {'children': [{'installs': 100000000,
#                              'name': 'Clash of Clans',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 44891723},
#                             {'installs': 100000000,
#                              'name': 'Clash Royale',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 23133508},
#                             {'installs': 500000000,
#                              'name': 'Candy Crush Saga',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 22426677},
#                             {'installs': 500000000,
#                              'name': 'My Talking Tom',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 14891223},
#                             {'installs': 100000000,
#                              'name': '8 Ball Pool',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 14198297},
#                             {'installs': 100000000,
#                              'name': 'Shadow Fight 2',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 10979062},
#                             {'installs': 500000000,
#                              'name': 'Pou',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 10485308},
#                             {'installs': 100000000,
#                              'name': 'Pokémon GO',
#                              'price': 0.0,
#                              'rating': 4.1,
#                              'reviews': 10424925},
#                             {'installs': 100000000,
#                              'name': 'Minion Rush: Despicable Me Official Game',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 10216538},
#                             {'installs': 1000000000,
#                              'name': 'Subway Surfers',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 27722264}],
#                'name': 'Game'},
#               {'children': [{'installs': 10000000,
#                              'name': 'Runtastic Running App & Mile Tracker',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 827597},
#                             {'installs': 10000000,
#                              'name': 'Nike+ Run Club',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 708674},
#                             {'installs': 10000000,
#                              'name': 'Period Tracker Clue: Period and '
#                                      'Ovulation Tracker',
#                              'price': 0.0,
#                              'rating': 4.8,
#                              'reviews': 570242},
#                             {'installs': 10000000,
#                              'name': 'Endomondo',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 559186},
#                             {'installs': 10000000,
#                              'name': 'Pedometer, Step Counter & Weight Loss '
#                                      'Tracker App',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 548021},
#                             {'installs': 10000000,
#                              'name': 'Water Drink Reminder',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 524299},
#                             {'installs': 10000000,
#                              'name': 'Runkeeper',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 501144},
#                             {'installs': 500000000,
#                              'name': 'Samsung Health',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 480208},
#                             {'installs': 100000000,
#                              'name': 'Period Tracker',
#                              'price': 0.0,
#                              'rating': 4.8,
#                              'reviews': 4559407},
#                             {'installs': 50000000,
#                              'name': 'Calorie Counter',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 1873516}],
#                'name': 'Health and fitness'},
#               {'children': [{'installs': 10000000,
#                              'name': 'Zillow: Find Houses for Sale & '
#                                      'Apartments for Rent',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 417907},
#                             {'installs': 10000000,
#                              'name': 'Houzz Interior Design Ideas',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 353799},
#                             {'installs': 10000000,
#                              'name': 'Trulia Real Estate & Rentals',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 175293},
#                             {'installs': 10000000,
#                              'name': 'Realtor.com Real Estate: Homes for Sale '
#                                      'and Rent',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 162243},
#                             {'installs': 5000000,
#                              'name': 'Alfred Home Security Camera',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 103305},
#                             {'installs': 5000000,
#                              'name': 'Trulia Rent Apartments & Homes',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 71419},
#                             {'installs': 10000000,
#                              'name': 'tinyCam Monitor FREE',
#                              'price': 0.0,
#                              'rating': 4.0,
#                              'reviews': 65914},
#                             {'installs': 5000000,
#                              'name': 'Real Estate sale & rent Trovit',
#                              'price': 0.0,
#                              'rating': 4.1,
#                              'reviews': 65913},
#                             {'installs': 1000000,
#                              'name': 'Room Creator Interior Design',
#                              'price': 0.0,
#                              'rating': 3.9,
#                              'reviews': 59660},
#                             {'installs': 1000000,
#                              'name': 'Home Security Camera WardenCam',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 43800}],
#                'name': 'House and home'},
#               {'children': [{'installs': 10000000,
#                              'name': 'MX Player Codec (ARMv7)',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 332083},
#                             {'installs': 10000000,
#                              'name': 'Cardboard',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 130272},
#                             {'installs': 10000000,
#                              'name': 'Aviary Stickers: Free Pack',
#                              'price': 0.0,
#                              'rating': 3.5,
#                              'reviews': 126862},
#                             {'installs': 5000000,
#                              'name': 'Aviary Effects: Classic',
#                              'price': 0.0,
#                              'rating': 3.8,
#                              'reviews': 67007},
#                             {'installs': 1000000,
#                              'name': 'Cool Popular Ringtones 2018 🔥',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 60170},
#                             {'installs': 5000000,
#                              'name': 'Wifi Connect Library',
#                              'price': 0.0,
#                              'rating': 3.9,
#                              'reviews': 58055},
#                             {'installs': 1000000,
#                              'name': 'ES Chromecast plugin',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 23859},
#                             {'installs': 1000000,
#                              'name': 'OpenCV Manager',
#                              'price': 0.0,
#                              'rating': 3.7,
#                              'reviews': 12657},
#                             {'installs': 1000000,
#                              'name': 'AZ Plugin 2 (newest)',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 11087},
#                             {'installs': 1000000,
#                              'name': 'Wifi Test',
#                              'price': 0.0,
#                              'rating': 4.0,
#                              'reviews': 8671}],
#                'name': 'Libraries and demo'},
#               {'children': [{'installs': 10000000,
#                              'name': 'Muslim Pro',
#                              'price': 0.0,
#                              'rating': 4.7,
#                              'reviews': 1133393},
#                             {'installs': 10000000,
#                              'name': 'happn',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 1118201},
#                             {'installs': 10000000,
#                              'name': 'Diary with lock',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 815893},
#                             {'installs': 10000000,
#                              'name': 'Family Locator',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 726074},
#                             {'installs': 10000000,
#                              'name': 'Daily Horoscope',
#                              'price': 0.0,
#                              'rating': 4.7,
#                              'reviews': 407589},
#                             {'installs': 10000000,
#                              'name': 'iHoroscope',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 398307},
#                             {'installs': 1000000,
#                              'name': 'Mirror',
#                              'price': 0.0,
#                              'rating': 3.9,
#                              'reviews': 32090},
#                             {'installs': 10000000,
#                              'name': 'Al',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 284670},
#                             {'installs': 100000000,
#                              'name': 'Tinder',
#                              'price': 0.0,
#                              'rating': 4.0,
#                              'reviews': 2789775},
#                             {'installs': 50000000,
#                              'name': 'Samsung+',
#                              'price': 0.0,
# ...
#                              'name': 'Myntra Online Shopping App',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 1315242},
#                             {'installs': 50000000,
#                              'name': 'The birth',
#                              'price': 0.0,
#                              'rating': 4.7,
#                              'reviews': 1084945},
#                             {'installs': 50000000,
#                              'name': 'letgo: Buy & Sell Used Stuff, Cars & '
#                                      'Real Estate',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 973270}],
#                'name': 'Shopping'},
#               {'children': [{'installs': 1000000000,
#                              'name': 'Facebook',
#                              'price': 0.0,
#                              'rating': 4.1,
#                              'reviews': 78158306},
#                             {'installs': 1000000000,
#                              'name': 'Instagram',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 66577313},
#                             {'installs': 500000000,
#                              'name': 'Snapchat',
#                              'price': 0.0,
#                              'rating': 4.0,
#                              'reviews': 17014787},
#                             {'installs': 500000000,
#                              'name': 'Facebook Lite',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 8606259},
#                             {'installs': 100000000,
#                              'name': 'VK',
#                              'price': 0.0,
#                              'rating': 3.8,
#                              'reviews': 5793284},
#                             {'installs': 100000000,
#                              'name': 'Tik Tok',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 5637451},
#                             {'installs': 1000000000,
#                              'name': 'Google+',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 4831125},
#                             {'installs': 100000000,
#                              'name': 'Pinterest',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 4305441},
#                             {'installs': 100000000,
#                              'name': 'Tango',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 3806669},
#                             {'installs': 100000000,
#                              'name': 'Badoo',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 3781770}],
#                'name': 'Social'},
#               {'children': [{'installs': 100000000,
#                              'name': 'FIFA Soccer',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 3909032},
#                             {'installs': 50000000,
#                              'name': 'Top Eleven 2018',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 3451011},
#                             {'installs': 50000000,
#                              'name': 'EA SPORTS UFC®',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 2371338},
#                             {'installs': 10000000,
#                              'name': 'PES 2018 PRO EVOLUTION SOCCER',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 1721943},
#                             {'installs': 50000000,
#                              'name': 'NBA LIVE Mobile Basketball',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 1690802},
#                             {'installs': 10000000,
#                              'name': 'Real Basketball',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 1605267},
#                             {'installs': 10000000,
#                              'name': 'Online Soccer Manager (OSM)',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 1312936},
#                             {'installs': 100000000,
#                              'name': '3D Bowling',
#                              'price': 0.0,
#                              'rating': 4.1,
#                              'reviews': 1076243},
#                             {'installs': 50000000,
#                              'name': '3D Tennis',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 1008012},
#                             {'installs': 50000000,
#                              'name': 'Wrestling Revolution 3D',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 989344}],
#                'name': 'Sports'},
#               {'children': [{'installs': 500000000,
#                              'name': 'Clean Master',
#                              'price': 0.0,
#                              'rating': 4.7,
#                              'reviews': 42916526},
#                             {'installs': 500000000,
#                              'name': 'Security Master',
#                              'price': 0.0,
#                              'rating': 4.7,
#                              'reviews': 24900999},
#                             {'installs': 100000000,
#                              'name': '360 Security',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 16771865},
#                             {'installs': 100000000,
#                              'name': 'DU Battery Saver',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 13479633},
#                             {'installs': 100000000,
#                              'name': 'Cache Cleaner',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 12759663},
#                             {'installs': 100000000,
#                              'name': 'Battery Doctor',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 8190074},
#                             {'installs': 500000000,
#                              'name': 'SHAREit',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 7790693},
#                             {'installs': 100000000,
#                              'name': 'AVG AntiVirus 2018 for Android Security',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 6207063},
#                             {'installs': 500000000,
#                              'name': 'Google Translate',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 5745093},
#                             {'installs': 1000000000,
#                              'name': 'Google',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 8033493}],
#                'name': 'Tools'},
#               {'children': [{'installs': 1000000000,
#                              'name': 'Maps',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 9235155},
#                             {'installs': 100000000,
#                              'name': 'Google Earth',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 2338655},
#                             {'installs': 1000000000,
#                              'name': 'Google Street View',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 2129689},
#                             {'installs': 100000000,
#                              'name': 'Booking.com Travel Deals',
#                              'price': 0.0,
#                              'rating': 4.7,
#                              'reviews': 1830388},
#                             {'installs': 100000000,
#                              'name': 'TripAdvisor Hotels Flights Restaurants '
#                                      'Attractions',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 1162837},
#                             {'installs': 50000000,
#                              'name': 'MAPS.ME',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 932870},
#                             {'installs': 50000000,
#                              'name': '2GIS: directory & navigator',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 768833},
#                             {'installs': 10000000,
#                              'name': 'GasBuddy: Find Cheap Gas',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 751551},
#                             {'installs': 10000000,
#                              'name': 'Where is my Train : Indian Railway & PNR '
#                                      'Status',
#                              'price': 0.0,
#                              'rating': 4.7,
#                              'reviews': 620534},
#                             {'installs': 10000000,
#                              'name': 'MakeMyTrip',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 599872}],
#                'name': 'Travel and local'},
#               {'children': [{'installs': 1000000000,
#                              'name': 'YouTube',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 25655305},
#                             {'installs': 100000000,
#                              'name': 'VivaVideo',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 9879473},
#                             {'installs': 100000000,
#                              'name': 'VideoShow',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 4016834},
#                             {'installs': 50000000,
#                              'name': 'DU Recorder',
#                              'price': 0.0,
#                              'rating': 4.8,
#                              'reviews': 2588730},
#                             {'installs': 100000000,
#                              'name': 'Dubsmash',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 1971777},
#                             {'installs': 50000000,
#                              'name': 'Vigo Video',
#                              'price': 0.0,
#                              'rating': 4.3,
#                              'reviews': 1615596},
#                             {'installs': 100000000,
#                              'name': 'VLC for Android',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 1032076},
#                             {'installs': 50000000,
#                              'name': 'KineMaster',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 1013867},
#                             {'installs': 50000000,
#                              'name': 'LIKE',
#                              'price': 0.0,
#                              'rating': 4.6,
#                              'reviews': 921868},
#                             {'installs': 500000000,
#                              'name': 'MX Player',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 6474426}],
#                'name': 'Video players'},
#               {'children': [{'installs': 50000000,
#                              'name': 'Weather & Clock Widget for Android',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 2371543},
#                             {'installs': 50000000,
#                              'name': 'AccuWeather: Daily Forecast & Live '
#                                      'Weather Reports',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 2053404},
#                             {'installs': 50000000,
#                              'name': 'The Weather Channel: Rain Forecast & '
#                                      'Storm Alerts',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 1558437},
#                             {'installs': 50000000,
#                              'name': 'GO Weather',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 1422858},
#                             {'installs': 10000000,
#                              'name': 'Yahoo Weather',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 1312037},
#                             {'installs': 10000000,
#                              'name': 'Weather by WeatherBug: Forecast, Radar & '
#                                      'Alerts',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 981995},
#                             {'installs': 10000000,
#                              'name': 'Yandex.Weather',
#                              'price': 0.0,
#                              'rating': 4.5,
#                              'reviews': 309617},
#                             {'installs': 10000000,
#                              'name': 'Weather 14 Days',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 279917},
#                             {'installs': 10000000,
#                              'name': 'Amber Weather',
#                              'price': 0.0,
#                              'rating': 4.4,
#                              'reviews': 260137},
#                             {'installs': 10000000,
#                              'name': 'wetter.com',
#                              'price': 0.0,
#                              'rating': 4.2,
#                              'reviews': 189313}],
#                'name': 'Weather'}],
#  'name': 'categories'}

# %% [markdown]
# ### Read csv file with all android apps and convert it to dictionary

# %%
df = pd.read_csv('db/data.csv')
data_dict = df.to_dict(orient = "records")
data_dict
# Out:
# [{'App': 'Photo Editor & Candy Camera & Grid & ScrapBook',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.1,
#   'Reviews': 159,
#   'Size': 19.0,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '7-Jan-18',
#   'Current Ver': '1.0.0',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Coloring book moana',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 3.9,
#   'Reviews': 967,
#   'Size': 14.0,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design;Pretend Play',
#   'Last_Updated': '15-Jan-18',
#   'Current Ver': '2.0.0',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.7,
#   'Reviews': 87510,
#   'Size': 8.7,
#   'Installs': 5000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '1-Aug-18',
#   'Current Ver': '1.2.4',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Sketch - Draw & Paint',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.5,
#   'Reviews': 215644,
#   'Size': 25.0,
#   'Installs': 50000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Teen',
#   'Genres': 'Art & Design',
#   'Last_Updated': '8-Jun-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': '4.2 and up'},
#  {'App': 'Pixel Draw - Number Art Coloring Book',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.3,
#   'Reviews': 967,
#   'Size': 2.8,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design;Creativity',
#   'Last_Updated': '20-Jun-18',
#   'Current Ver': '1.1',
#   'Android_Ver': '4.4 and up'},
#  {'App': 'Paper flowers instructions',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.4,
#   'Reviews': 167,
#   'Size': 5.6,
#   'Installs': 50000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '26-Mar-17',
#   'Current Ver': '1',
#   'Android_Ver': '2.3 and up'},
#  {'App': 'Smoke Effect Photo Maker - Smoke Editor',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 3.8,
#   'Reviews': 178,
#   'Size': 19.0,
#   'Installs': 50000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '26-Apr-18',
#   'Current Ver': '1.1',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Infinite Painter',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.1,
#   'Reviews': 36815,
#   'Size': 29.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '14-Jun-18',
#   'Current Ver': '6.1.61.1',
#   'Android_Ver': '4.2 and up'},
#  {'App': 'Garden Coloring Book',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.4,
#   'Reviews': 13791,
#   'Size': 33.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '20-Sep-17',
#   'Current Ver': '2.9.2',
#   'Android_Ver': '3.0 and up'},
#  {'App': 'Kids Paint Free - Drawing Fun',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.7,
#   'Reviews': 121,
#   'Size': 3.1,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design;Creativity',
#   'Last_Updated': '3-Jul-18',
#   'Current Ver': '2.8',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Text on Photo - Fonteee',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.4,
#   'Reviews': 13880,
#   'Size': 28.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '27-Oct-17',
#   'Current Ver': '1.0.4',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Name Art Photo Editor - Focus n Filters',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.4,
#   'Reviews': 8788,
#   'Size': 12.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '31-Jul-18',
#   'Current Ver': '1.0.15',
#   'Android_Ver': '4.0 and up'},
#  {'App': 'Tattoo Name On My Photo Editor',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.2,
#   'Reviews': 44829,
#   'Size': 20.0,
#   'Installs': 10000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Teen',
#   'Genres': 'Art & Design',
#   'Last_Updated': '2-Apr-18',
#   'Current Ver': '3.8',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Mandala Coloring Book',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.6,
#   'Reviews': 4326,
#   'Size': 21.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '26-Jun-18',
#   'Current Ver': '1.0.4',
#   'Android_Ver': '4.4 and up'},
#  {'App': '3D Color Pixel by Number - Sandbox Art Coloring',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.4,
#   'Reviews': 1518,
#   'Size': 37.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '3-Aug-18',
#   'Current Ver': '1.2.3',
#   'Android_Ver': '2.3 and up'},
#  {'App': 'Learn To Draw Kawaii Characters',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 3.2,
#   'Reviews': 55,
#   'Size': 2.7,
#   'Installs': 5000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '6-Jun-18',
#   'Current Ver': nan,
#   'Android_Ver': '4.2 and up'},
#  {'App': 'Photo Designer - Write your name with shapes',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.7,
#   'Reviews': 3632,
#   'Size': 5.5,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '31-Jul-18',
#   'Current Ver': '3.1',
#   'Android_Ver': '4.1 and up'},
#  {'App': '350 Diy Room Decor Ideas',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.5,
#   'Reviews': 27,
#   'Size': 17.0,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '7-Nov-17',
#   'Current Ver': '1',
#   'Android_Ver': '2.3 and up'},
#  {'App': 'FlipaClip - Cartoon animation',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.3,
#   'Reviews': 194216,
#   'Size': 39.0,
#   'Installs': 5000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '3-Aug-18',
#   'Current Ver': '2.2.5',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'ibis Paint X',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.6,
#   'Reviews': 224399,
#   'Size': 31.0,
#   'Installs': 10000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '30-Jul-18',
#   'Current Ver': '5.5.4',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Logo Maker - Small Business',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.0,
#   'Reviews': 450,
#   'Size': 14.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '20-Apr-18',
#   'Current Ver': '4',
#   'Android_Ver': '4.1 and up'},
#  {'App': "Boys Photo Editor - Six Pack & Men's Suit",
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.1,
#   'Reviews': 654,
#   'Size': 12.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '20-Mar-18',
#   'Current Ver': '1.1',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Superheroes Wallpapers | 4K Backgrounds',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.7,
#   'Reviews': 7699,
#   'Size': 4.2,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone 10+',
#   'Genres': 'Art & Design',
#   'Last_Updated': '12-Jul-18',
#   'Current Ver': '2.2.6.2',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Mcqueen Coloring pages',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': nan,
#   'Reviews': 61,
#   'Size': 7.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design;Action & Adventure',
#   'Last_Updated': '7-Mar-18',
#   'Current Ver': '1.0.0',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'HD Mickey Minnie Wallpapers',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.7,
#   'Reviews': 118,
#   'Size': 23.0,
#   'Installs': 50000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '7-Jul-18',
#   'Current Ver': '1.1.3',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Harley Quinn wallpapers HD',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.8,
#   'Reviews': 192,
#   'Size': 6.0,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '25-Apr-18',
#   'Current Ver': '1.5',
#   'Android_Ver': '3.0 and up'},
#  {'App': 'Colorfit - Drawing & Coloring',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.7,
#   'Reviews': 20260,
#   'Size': 25.0,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design;Creativity',
#   'Last_Updated': '11-Oct-17',
#   'Current Ver': '1.0.8',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Animated Photo Editor',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.1,
#   'Reviews': 203,
#   'Size': 6.1,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '21-Mar-18',
#   'Current Ver': '1.03',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Pencil Sketch Drawing',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 3.9,
#   'Reviews': 136,
#   'Size': 4.6,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '12-Jul-18',
#   'Current Ver': '6',
#   'Android_Ver': '2.3 and up'},
#  {'App': 'Easy Realistic Drawing Tutorial',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.1,
#   'Reviews': 223,
#   'Size': 4.2,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '22-Aug-17',
#   'Current Ver': '1',
#   'Android_Ver': '2.3 and up'},
#  {'App': 'Pink Silver Bow Keyboard Theme',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.2,
#   'Reviews': 1120,
#   'Size': 9.2,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '12-Jul-18',
#   'Current Ver': '6.7.12.2018',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Art Drawing Ideas',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.1,
#   'Reviews': 227,
#   'Size': 5.2,
#   'Installs': 50000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '31-May-18',
#   'Current Ver': '1.2',
#   'Android_Ver': '2.3 and up'},
#  {'App': 'Anime Manga Coloring Book',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.5,
#   'Reviews': 5035,
#   'Size': 11.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '19-Jul-18',
#   'Current Ver': '2.2',
#   'Android_Ver': '4.0 and up'},
#  {'App': 'Easy Origami Ideas',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.2,
#   'Reviews': 1015,
#   'Size': 11.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '6-Jan-18',
#   'Current Ver': '1.1.0',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'I Creative Idea',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.7,
#   'Reviews': 353,
#   'Size': 4.2,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Teen',
#   'Genres': 'Art & Design',
#   'Last_Updated': '27-Apr-18',
#   'Current Ver': '1.6',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'How to draw Ladybug and Cat Noir',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 3.8,
#   'Reviews': 564,
#   'Size': 9.2,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '11-Jul-18',
#   'Current Ver': '2.1',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'UNICORN - Color By Number & Pixel Art Coloring',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.7,
#   'Reviews': 8145,
#   'Size': 24.0,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design;Creativity',
#   'Last_Updated': '2-Aug-18',
#   'Current Ver': '1.0.9',
#   'Android_Ver': '4.4 and up'},
#  {'App': 'Floor Plan Creator',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.1,
#   'Reviews': 36639,
#   'Size': nan,
#   'Installs': 5000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '14-Jul-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': '2.3.3 and up'},
#  {'App': 'PIP Camera - PIP Collage Maker',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.7,
#   'Reviews': 158,
#   'Size': 11.0,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '29-Nov-17',
#   'Current Ver': '1.3',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'How To Color Disney Princess - Coloring Pages',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.0,
#   'Reviews': 591,
#   'Size': 9.4,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '31-Mar-18',
#   'Current Ver': '1',
#   'Android_Ver': '4.0 and up'},
#  {'App': 'Drawing Clothes Fashion Ideas',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.2,
#   'Reviews': 117,
#   'Size': 15.0,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '20-Jul-18',
#   'Current Ver': '2.0.1',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Sad Poetry Photo Frames 2018',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.5,
#   'Reviews': 176,
#   'Size': 10.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '2-Apr-18',
#   'Current Ver': '1',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Textgram - write on photos',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.4,
#   'Reviews': 295221,
#   'Size': nan,
#   'Installs': 10000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '30-Jul-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': 'Varies with device'},
#  {'App': 'Paint Splash!',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 3.8,
#   'Reviews': 2206,
#   'Size': 1.2,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design;Creativity',
#   'Last_Updated': '15-Apr-18',
#   'Current Ver': '1.46',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Popsicle Sticks and Similar DIY Craft Ideas',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.2,
#   'Reviews': 26,
#   'Size': 12.0,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '3-Jan-18',
#   'Current Ver': '1.0.0',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Canva: Poster, banner, card maker & graphic design',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.7,
#   'Reviews': 174531,
#   'Size': 24.0,
#   'Installs': 10000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '31-Jul-18',
#   'Current Ver': '1.6.1',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Install images with music to make video without Net - 2018',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.6,
#   'Reviews': 1070,
#   'Size': 26.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '14-Nov-17',
#   'Current Ver': '1.6',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Little Teddy Bear Colouring Book Game',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.2,
#   'Reviews': 85,
#   'Size': 8.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '17-Dec-17',
#   'Current Ver': '2.0.0',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'How To Draw Food',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.3,
#   'Reviews': 845,
#   'Size': 7.9,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last_Updated': '28-May-18',
#   'Current Ver': '1',
#   'Android_Ver': '2.3 and up'},
#  {'App': 'Monster Truck Stunt 3D 2019',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.2,
#   'Reviews': 367,
#   'Size': 25.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '10-May-18',
#   'Current Ver': '1',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Real Tractor Farming',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.0,
#   'Reviews': 1598,
#   'Size': 56.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '26-Jul-18',
#   'Current Ver': '11',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Ultimate F1 Racing Championship',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 3.8,
#   'Reviews': 284,
#   'Size': 57.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '26-Jul-18',
#   'Current Ver': '3',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Used Cars and Trucks for Sale',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.6,
#   'Reviews': 17057,
#   'Size': nan,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '30-Jul-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': 'Varies with device'},
#  {'App': 'American Muscle Car Race',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 3.9,
#   'Reviews': 129,
#   'Size': 35.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '26-Jul-18',
#   'Current Ver': '3',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Offroad Oil Tanker Driver Transport Truck 2019',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.3,
#   'Reviews': 542,
#   'Size': 33.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '31-Jul-18',
#   'Current Ver': '4',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Tickets SDA 2018 and Exam from the State Traffic Safety Inspectorate with Drom.ru',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.9,
#   'Reviews': 10479,
#   'Size': 33.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '18-Jul-18',
#   'Current Ver': '1.7.1',
#   'Android_Ver': '4.0 and up'},
#  {'App': 'Gas Prices (Germany only)',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.4,
#   'Reviews': 805,
#   'Size': 5.6,
#   'Installs': 50000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '29-Jul-18',
#   'Current Ver': '2.5.1',
#   'Android_Ver': '4.4 and up'},
#  {'App': 'Extreme Rally Championship',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.2,
#   'Reviews': 129,
#   'Size': 54.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '26-Jul-18',
#   'Current Ver': '3',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Restart Navigator',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.0,
#   'Reviews': 1403,
#   'Size': 0.201,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '26-Aug-14',
#   'Current Ver': '1.0.1',
#   'Android_Ver': '2.2 and up'},
#  {'App': 'REG - Check the regnumber, find information about Swedish vehicles',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 3.9,
#   'Reviews': 3971,
#   'Size': 3.6,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '30-Jul-18',
#   'Current Ver': '2.493',
#   'Android_Ver': '4.4 and up'},
#  {'App': 'CityBus Lviv',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.6,
#   'Reviews': 534,
#   'Size': 5.7,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '8-Jul-18',
#   'Current Ver': '1.9.1',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'CDL Practice Test 2018 Edition',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.9,
#   'Reviews': 7774,
#   'Size': 17.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '3-Jul-18',
#   'Current Ver': '1.7',
#   'Android_Ver': '4.2 and up'},
#  {'App': 'ezETC (ETC balance inquiry, meter trial, real-time traffic)',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.3,
#   'Reviews': 38846,
#   'Size': 8.6,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '28-Jul-18',
#   'Current Ver': '2.20 Build 02',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Free VIN Report for Used Cars',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.6,
#   'Reviews': 2431,
#   'Size': 2.4,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '12-Jun-18',
#   'Current Ver': '1.37',
#   'Android_Ver': '4.0 and up'},
#  {'App': 'DMV Permit Practice Test 2018 Edition',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.9,
#   'Reviews': 6090,
#   'Size': 27.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '3-Jul-18',
#   'Current Ver': '1.7',
#   'Android_Ver': '4.2 and up'},
#  {'App': 'Check Vehicle Tax',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 3.9,
#   'Reviews': 295,
#   'Size': 2.7,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '30-Jul-18',
#   'Current Ver': '0.2.1',
#   'Android_Ver': '4.4 and up'},
#  {'App': 'Used Cars Mexico',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.0,
#   'Reviews': 190,
#   'Size': 2.5,
#   'Installs': 50000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '14-Oct-16',
#   'Current Ver': '1',
#   'Android_Ver': '2.3 and up'},
#  {'App': 'Ulysse Speedometer',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.3,
#   'Reviews': 40211,
#   'Size': nan,
#   'Installs': 5000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '30-Jul-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': 'Varies with device'},
#  {'App': 'REPUVE',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 3.9,
#   'Reviews': 356,
#   'Size': nan,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '25-May-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': 'Varies with device'},
#  {'App': 'Used cars for sale - Trovit',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.2,
#   'Reviews': 52530,
#   'Size': 7.0,
#   'Installs': 5000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '16-Jul-18',
#   'Current Ver': '4.47.3',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Fines of the State Traffic Safety Inspectorate are official: inspection, payment of fines',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.8,
#   'Reviews': 116986,
#   'Size': 35.0,
#   'Installs': 5000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '2-Aug-18',
#   'Current Ver': '1.9.7',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'SK Enca Direct Malls - Used Cars Search',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 3.6,
#   'Reviews': 1379,
#   'Size': 16.0,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '2-Aug-18',
#   'Current Ver': '2.2.21',
#   'Android_Ver': '4.2 and up'},
#  {'App': 'Android Auto - Maps, Media, Messaging & Voice',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.2,
#   'Reviews': 271920,
#   'Size': 16.0,
#   'Installs': 10000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Teen',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '11-Jul-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': '5.0 and up'},
#  {'App': 'PDD-UA',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.8,
#   'Reviews': 736,
#   'Size': nan,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '29-Jul-18',
#   'Current Ver': '2.9',
#   'Android_Ver': '2.3.3 and up'},
#  {'App': 'Tickets SDA 2019 + Exam RF',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.8,
#   'Reviews': 7021,
#   'Size': 17.0,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '27-Jul-18',
#   'Current Ver': '1.79',
#   'Android_Ver': '4.0 and up'},
#  {'App': 'Super Cars Wallpapers And Backgrounds',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.6,
#   'Reviews': 197,
#   'Size': 3.4,
#   'Installs': 50000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '14-Jun-18',
#   'Current Ver': '1.3',
#   'Android_Ver': '4.0 and up'},
#  {'App': 'Police Lights, Sirens & Follow Me',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.5,
#   'Reviews': 737,
#   'Size': 8.9,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '8-Jun-18',
#   'Current Ver': '2.3.5.1',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Police Detector (Speed Camera Radar)',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.3,
#   'Reviews': 3574,
#   'Size': 3.9,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone 10+',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '4-Jul-18',
#   'Current Ver': '1.6',
#   'Android_Ver': '4.0 and up'},
#  {'App': 'Best Car Wallpapers',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.5,
#   'Reviews': 994,
#   'Size': 2.9,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '27-Mar-18',
#   'Current Ver': '1.6',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Tickets + PDA 2018 Exam',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.9,
#   'Reviews': 197136,
#   'Size': 38.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '15-Jul-18',
#   'Current Ver': '8.31',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Pick Your Part Garage',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 3.9,
#   'Reviews': 142,
#   'Size': 32.0,
#   'Installs': 50000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '24-Jul-18',
#   'Current Ver': '1.1.5.0',
#   'Android_Ver': '6.0 and up'},
#  {'App': 'PakWheels: Buy & Sell Cars',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.4,
#   'Reviews': 15168,
#   'Size': 37.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '27-Jul-18',
#   'Current Ver': '10.0.2',
#   'Android_Ver': '4.2 and up'},
#  {'App': 'Supervision service',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.0,
#   'Reviews': 2155,
#   'Size': 15.0,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '30-Jul-18',
#   'Current Ver': '1.10.3',
#   'Android_Ver': '5.0 and up'},
#  {'App': 'Speed Camera Detector - Traffic & Speed Alert',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.3,
#   'Reviews': 138,
#   'Size': 5.4,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '23-Jul-18',
#   'Current Ver': '1',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Used car search Goo net whole car Go to net',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 3.7,
#   'Reviews': 5414,
#   'Size': 18.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '23-Jul-18',
#   'Current Ver': '3.20.1',
#   'Android_Ver': '4.4 and up'},
#  {'App': 'CarMax – Cars for Sale: Search Used Car Inventory',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.4,
#   'Reviews': 21777,
#   'Size': nan,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '4-Aug-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': 'Varies with device'},
#  {'App': 'BEST CAR SOUNDS',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.3,
#   'Reviews': 348,
#   'Size': 38.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '29-Jul-18',
#   'Current Ver': '1.0.3',
#   'Android_Ver': '2.3 and up'},
#  {'App': 'RST - Sale of cars on the PCT',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 3.2,
#   'Reviews': 250,
#   'Size': 1.1,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '27-Apr-18',
#   'Current Ver': '1.4',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'AutoScout24 Switzerland – Find your new car',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.6,
#   'Reviews': 13372,
#   'Size': nan,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '3-Aug-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': 'Varies with device'},
#  {'App': 'Zona Azul Digital Fácil SP CET - OFFICIAL São Paulo',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.6,
#   'Reviews': 7880,
#   'Size': nan,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '10-May-18',
#   'Current Ver': '4.6.5',
#   'Android_Ver': 'Varies with device'},
#  {'App': 'SMS Park',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.5,
#   'Reviews': 3617,
#   'Size': 7.9,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '16-May-18',
#   'Current Ver': '2.8.2',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'SKencar',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 3.7,
#   'Reviews': 4806,
#   'Size': 35.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '31-Jul-18',
#   'Current Ver': '4.0.3',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Fuelio: Gas log & costs',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.6,
#   'Reviews': 65786,
#   'Size': nan,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '2-Aug-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'auto fines',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.6,
#   'Reviews': 31433,
#   'Size': 17.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '2-Aug-18',
#   'Current Ver': '1.4',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Used car is the first car - used car purchase, used car quotation, dealer information to',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.6,
#   'Reviews': 5097,
#   'Size': 19.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '23-Jul-18',
#   'Current Ver': '1.5.18',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'All of the parking lot - National Park application (parking lot search / parking sharing / discount payment)',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.0,
#   'Reviews': 1754,
#   'Size': 14.0,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '2-Jun-18',
#   'Current Ver': '2.3.4',
#   'Android_Ver': '4.0 and up'},
#  {'App': 'Inquiry Fines and Debits of Vehicles',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.4,
#   'Reviews': 2680,
#   'Size': 2.2,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '20-Mar-18',
#   'Current Ver': '1.03',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Gas Station',
#   'Category': 'AUTO_AND_VEHICLES',
#   'Rating': 4.0,
#   'Reviews': 1288,
#   'Size': 4.5,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Auto & Vehicles',
#   'Last_Updated': '21-Apr-18',
#   'Current Ver': '2.17',
#   'Android_Ver': '4.0 and up'},
#  {'App': 'Hush - Beauty for Everyone',
#   'Category': 'BEAUTY',
#   'Rating': 4.7,
#   'Reviews': 18900,
#   'Size': 17.0,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '2-Aug-18',
#   'Current Ver': '6.10.1',
#   'Android_Ver': '5.0 and up'},
#  {'App': 'ipsy: Makeup, Beauty, and Tips',
#   'Category': 'BEAUTY',
#   'Rating': 4.9,
#   'Reviews': 49790,
#   'Size': 14.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '9-Nov-17',
#   'Current Ver': '2.3.0',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Natural recipes for your beauty',
#   'Category': 'BEAUTY',
#   'Rating': 4.7,
#   'Reviews': 1150,
#   'Size': 9.8,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '15-May-18',
#   'Current Ver': '4',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'BestCam Selfie-selfie, beauty camera, photo editor',
#   'Category': 'BEAUTY',
#   'Rating': 3.9,
#   'Reviews': 1739,
#   'Size': 21.0,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '12-Jul-18',
#   'Current Ver': '1.0.6',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Mirror - Zoom & Exposure -',
#   'Category': 'BEAUTY',
#   'Rating': 3.9,
#   'Reviews': 32090,
#   'Size': nan,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '24-Oct-16',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': 'Varies with device'},
#  {'App': 'Beauty Selfie Camera',
#   'Category': 'BEAUTY',
#   'Rating': 4.2,
#   'Reviews': 2225,
#   'Size': 52.0,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '28-Feb-18',
#   'Current Ver': '1.6',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Hairstyles step by step',
#   'Category': 'BEAUTY',
#   'Rating': 4.6,
#   'Reviews': 4369,
#   'Size': 14.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '25-Jul-18',
#   'Current Ver': '1.9',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Filters for Selfie',
#   'Category': 'BEAUTY',
#   'Rating': 4.3,
#   'Reviews': 8572,
#   'Size': 25.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '10-May-18',
#   'Current Ver': '1.1.0',
#   'Android_Ver': '4.0 and up'},
#  {'App': 'Tie - Always be happy',
#   'Category': 'BEAUTY',
#   'Rating': 4.7,
#   'Reviews': 964,
#   'Size': 9.0,
#   'Installs': 50000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '21-Jun-18',
#   'Current Ver': '4',
#   'Android_Ver': '4.2 and up'},
#  {'App': 'Ulta Beauty',
#   'Category': 'BEAUTY',
#   'Rating': 4.7,
#   'Reviews': 42050,
#   'Size': nan,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '5-Jun-18',
#   'Current Ver': '5.4',
#   'Android_Ver': '5.0 and up'},
#  {'App': 'Prom MakeUp Tutorial',
#   'Category': 'BEAUTY',
#   'Rating': 4.8,
#   'Reviews': 104,
#   'Size': 12.0,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '26-Jun-18',
#   'Current Ver': '1.3',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Selfie Camera',
#   'Category': 'BEAUTY',
#   'Rating': 4.2,
#   'Reviews': 17934,
#   'Size': nan,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '12-Sep-17',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': 'Varies with device'},
#  {'App': 'Sweet Selfie Beauty Camera',
#   'Category': 'BEAUTY',
#   'Rating': 4.3,
#   'Reviews': 601,
#   'Size': 35.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '2-Jun-18',
#   'Current Ver': '2.0.0',
#   'Android_Ver': '4.0 and up'},
#  {'App': 'Colors of white in Urdu',
#   'Category': 'BEAUTY',
#   'Rating': 4.5,
#   'Reviews': 36,
#   'Size': 6.7,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '26-Jul-18',
#   'Current Ver': '6',
#   'Android_Ver': '4.0 and up'},
#  {'App': 'Selfie Camera Photo Editor & Filter & Sticker',
#   'Category': 'BEAUTY',
#   'Rating': 4.1,
#   'Reviews': 187,
#   'Size': 30.0,
#   'Installs': 50000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Teen',
#   'Genres': 'Beauty',
#   'Last_Updated': '24-Jul-18',
#   'Current Ver': '3.0.1',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Wrinkles and rejuvenation',
#   'Category': 'BEAUTY',
#   'Rating': nan,
#   'Reviews': 182,
#   'Size': 5.7,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone 10+',
#   'Genres': 'Beauty',
#   'Last_Updated': '20-Sep-17',
#   'Current Ver': '8',
#   'Android_Ver': '3.0 and up'},
#  {'App': 'Eyes Makeup Beauty Tips',
#   'Category': 'BEAUTY',
#   'Rating': 4.2,
#   'Reviews': 30,
#   'Size': 2.9,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '9-Apr-18',
#   'Current Ver': '3.3.9',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Photo Editor 2018',
#   'Category': 'BEAUTY',
#   'Rating': 4.5,
#   'Reviews': 134,
#   'Size': 17.0,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '1-Mar-18',
#   'Current Ver': '1.2',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Step By Step Eyes Makeup Tutorial',
#   'Category': 'BEAUTY',
#   'Rating': 4.4,
#   'Reviews': 74,
#   'Size': 2.9,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '5-Apr-18',
#   'Current Ver': '2.3.09',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Beauty Camera - Selfie Camera',
#   'Category': 'BEAUTY',
#   'Rating': 4.0,
#   'Reviews': 113715,
#   'Size': nan,
#   'Installs': 10000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '3-Aug-17',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': 'Varies with device'},
#  {'App': 'Girls Hairstyles',
#   'Category': 'BEAUTY',
#   'Rating': 4.1,
#   'Reviews': 3595,
#   'Size': nan,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '24-May-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': '4.0 and up'},
#  {'App': 'Mirror Camera (Mirror + Selfie Camera)',
#   'Category': 'BEAUTY',
#   'Rating': 4.1,
#   'Reviews': 9315,
#   'Size': 2.6,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '21-Nov-17',
#   'Current Ver': '1.4.2',
#   'Android_Ver': '4.0 and up'},
#  {'App': 'Beauty Tips - Beauty Tips in Sinhala',
#   'Category': 'BEAUTY',
#   'Rating': 4.4,
#   'Reviews': 75,
#   'Size': 4.2,
#   'Installs': 50000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '18-Oct-17',
#   'Current Ver': '1.0.0',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Haircut Tutorials/Haircut Videos',
#   'Category': 'BEAUTY',
#   'Rating': 4.6,
#   'Reviews': 38,
#   'Size': 7.1,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '29-May-18',
#   'Current Ver': '1',
#   'Android_Ver': '4.0 and up'},
#  {'App': 'Sephora: Skin Care, Beauty Makeup & Fragrance Shop',
#   'Category': 'BEAUTY',
#   'Rating': 4.5,
#   'Reviews': 26834,
#   'Size': 57.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '24-Jul-18',
#   'Current Ver': '18.5',
#   'Android_Ver': '5.0 and up'},
#  {'App': 'Manicure - nail design',
#   'Category': 'BEAUTY',
#   'Rating': nan,
#   'Reviews': 119,
#   'Size': 3.7,
#   'Installs': 50000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '23-Jul-18',
#   'Current Ver': '1.3',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Sticker Camera - Selfie Filters, Beauty Camera',
#   'Category': 'BEAUTY',
#   'Rating': 3.9,
#   'Reviews': 2277,
#   'Size': 22.0,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '12-Jul-18',
#   'Current Ver': '1.1.0',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Filters for B Live',
#   'Category': 'BEAUTY',
#   'Rating': 4.4,
#   'Reviews': 2280,
#   'Size': 24.0,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '14-May-18',
#   'Current Ver': '1.1.0',
#   'Android_Ver': '4.0 and up'},
#  {'App': 'Skin Care and Natural Beauty',
#   'Category': 'BEAUTY',
#   'Rating': nan,
#   'Reviews': 654,
#   'Size': 7.4,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Teen',
#   'Genres': 'Beauty',
#   'Last_Updated': '17-Jul-18',
#   'Current Ver': '1.15',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Facial Wrinkle Reduction',
#   'Category': 'BEAUTY',
#   'Rating': 4.6,
#   'Reviews': 184,
#   'Size': 21.0,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '2-Jul-18',
#   'Current Ver': '1.5',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Makeup Videos',
#   'Category': 'BEAUTY',
#   'Rating': 3.8,
#   'Reviews': 9,
#   'Size': 3.4,
#   'Installs': 5000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '7-Jun-18',
#   'Current Ver': '1',
#   'Android_Ver': '4.0 and up'},
#  {'App': 'Secrets of beauty, youth and health',
#   'Category': 'BEAUTY',
#   'Rating': nan,
#   'Reviews': 77,
#   'Size': 2.9,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Mature 17+',
#   'Genres': 'Beauty',
#   'Last_Updated': '8-Aug-17',
#   'Current Ver': '2',
#   'Android_Ver': '2.3 and up'},
#  {'App': 'Recipes and tips for losing weight',
#   'Category': 'BEAUTY',
#   'Rating': nan,
#   'Reviews': 35,
#   'Size': 3.1,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone 10+',
#   'Genres': 'Beauty',
#   'Last_Updated': '11-Dec-17',
#   'Current Ver': '2',
#   'Android_Ver': '3.0 and up'},
#  {'App': 'Discover Color',
#   'Category': 'BEAUTY',
#   'Rating': 4.0,
#   'Reviews': 364,
#   'Size': 6.4,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '24-May-18',
#   'Current Ver': '1.1',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Eyeliner step by step 2018',
#   'Category': 'BEAUTY',
#   'Rating': 4.3,
#   'Reviews': 18,
#   'Size': 3.2,
#   'Installs': 5000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '1-Jun-18',
#   'Current Ver': '1.2.13',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Dresses Ideas & Fashions +3000',
#   'Category': 'BEAUTY',
#   'Rating': 4.5,
#   'Reviews': 473,
#   'Size': 8.2,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Mature 17+',
#   'Genres': 'Beauty',
#   'Last_Updated': '1-Mar-17',
#   'Current Ver': '1.0.2.0',
#   'Android_Ver': '1.6 and up'},
#  {'App': 'Lady adviser (beauty, health)',
#   'Category': 'BEAUTY',
#   'Rating': nan,
#   'Reviews': 30,
#   'Size': 9.9,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Mature 17+',
#   'Genres': 'Beauty',
#   'Last_Updated': '24-Jan-18',
#   'Current Ver': '3',
#   'Android_Ver': '3.0 and up'},
#  {'App': 'Step By Step Hairstyles For Women',
#   'Category': 'BEAUTY',
#   'Rating': 4.1,
#   'Reviews': 66,
#   'Size': 2.9,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '5-Apr-18',
#   'Current Ver': '3.1.89',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Rainbow Camera',
#   'Category': 'BEAUTY',
#   'Rating': 3.7,
#   'Reviews': 3871,
#   'Size': 23.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '30-Jul-18',
#   'Current Ver': '2.2.0',
#   'Android_Ver': '4.0 and up'},
#  {'App': 'Methods of teeth whitening',
#   'Category': 'BEAUTY',
#   'Rating': 4.7,
#   'Reviews': 257,
#   'Size': 4.6,
#   'Installs': 50000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '7-Aug-17',
#   'Current Ver': '1',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Girls hairstyles 2018',
#   'Category': 'BEAUTY',
#   'Rating': 4.2,
#   'Reviews': 62,
#   'Size': 3.1,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Beauty',
#   'Last_Updated': '28-May-18',
#   'Current Ver': '1.9.2',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Wattpad 📖 Free Books',
#   'Category': 'BOOKS_AND_REFERENCE',
#   'Rating': 4.6,
#   'Reviews': 2914724,
#   'Size': nan,
#   'Installs': 100000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Teen',
#   'Genres': 'Books & Reference',
#   'Last_Updated': '1-Aug-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': 'Varies with device'},
#  {'App': 'E-Book Read - Read Book for free',
#   'Category': 'BOOKS_AND_REFERENCE',
#   'Rating': 4.5,
#   'Reviews': 1857,
#   'Size': 4.9,
#   'Installs': 50000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Books & Reference',
#   'Last_Updated': '3-Aug-18',
#   'Current Ver': '1.3.2',
#   'Android_Ver': '4.4 and up'},
#  {'App': 'Download free book with green book',
#   'Category': 'BOOKS_AND_REFERENCE',
#   'Rating': 4.6,
#   'Reviews': 4478,
#   'Size': 9.5,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone 10+',
#   'Genres': 'Books & Reference',
#   'Last_Updated': '31-Jul-17',
#   'Current Ver': '1.1',
#   'Android_Ver': '4.0 and up'},
#  {'App': 'Wikipedia',
#   'Category': 'BOOKS_AND_REFERENCE',
#   'Rating': 4.4,
#   'Reviews': 577550,
#   'Size': nan,
#   'Installs': 10000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Books & Reference',
#   'Last_Updated': '2-Aug-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': 'Varies with device'},
#  {'App': 'Amazon Kindle',
#   'Category': 'BOOKS_AND_REFERENCE',
#   'Rating': 4.2,
#   'Reviews': 814080,
#   'Size': nan,
#   'Installs': 100000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Teen',
#   'Genres': 'Books & Reference',
#   'Last_Updated': '27-Jul-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': 'Varies with device'},
#  {'App': 'Cool Reader',
#   'Category': 'BOOKS_AND_REFERENCE',
#   'Rating': 4.5,
#   'Reviews': 246315,
#   'Size': nan,
#   'Installs': 10000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Books & Reference',
# ...
#   'Android_Ver': '5.0 and up'},
#  {'App': "McDonald's",
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 3.6,
#   'Reviews': 145323,
#   'Size': 42.0,
#   'Installs': 10000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '31-Jul-18',
#   'Current Ver': '5.15.0',
#   'Android_Ver': '4.4 and up'},
#  {'App': 'Easy and Fast Recipes',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': nan,
#   'Reviews': 95,
#   'Size': 12.0,
#   'Installs': 50000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '6-Jan-18',
#   'Current Ver': '3.0.1',
#   'Android_Ver': '2.3 and up'},
#  {'App': 'Cookpad - FREE recipe search makes fun cooking · musical making!',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.1,
#   'Reviews': 64784,
#   'Size': 13.0,
#   'Installs': 10000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '2-Aug-18',
#   'Current Ver': '18.6.0.10',
#   'Android_Ver': '5.0 and up'},
#  {'App': 'DELISH KITCHEN - FREE recipe movies make food fun and easy!',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.6,
#   'Reviews': 32997,
#   'Size': 13.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '4-Aug-18',
#   'Current Ver': '2.2.7',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Sumine side dish - dish recipe side dish',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': nan,
#   'Reviews': 82,
#   'Size': 4.9,
#   'Installs': 10000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '23-Jun-18',
#   'Current Ver': '1.1',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Easy Recipes',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.7,
#   'Reviews': 2707,
#   'Size': 8.9,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '15-May-18',
#   'Current Ver': '2.12',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Delicious Recipes',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.7,
#   'Reviews': 129737,
#   'Size': nan,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Teen',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '3-Aug-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': 'Varies with device'},
#  {'App': 'Tastely',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.7,
#   'Reviews': 611136,
#   'Size': 19.0,
#   'Installs': 10000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '13-Jul-18',
#   'Current Ver': '3.2.0d',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Pastry & Cooking (Without Net)',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.7,
#   'Reviews': 6118,
#   'Size': nan,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '7-Jul-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': 'Varies with device'},
#  {'App': 'Frigo Magic: Easy recipe idea and anti-waste',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.1,
#   'Reviews': 2473,
#   'Size': 14.0,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '28-Jul-18',
#   'Current Ver': '3.1.5',
#   'Android_Ver': '4.4 and up'},
#  {'App': "McDonald's - McDonald's Japan",
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 3.4,
#   'Reviews': 109784,
#   'Size': 64.0,
#   'Installs': 10000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '3-Aug-18',
#   'Current Ver': '4.0.30',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Debonairs Pizza',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 3.8,
#   'Reviews': 3320,
#   'Size': 8.4,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '4-Aug-18',
#   'Current Ver': '1.9.117',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Popeyes® App',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 3.7,
#   'Reviews': 61,
#   'Size': 11.0,
#   'Installs': 50000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '23-Jul-18',
#   'Current Ver': '1.0.2',
#   'Android_Ver': '4.1 and up'},
#  {'App': "Dunkin' Donuts",
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.2,
#   'Reviews': 68103,
#   'Size': 66.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '20-Jun-18',
#   'Current Ver': '5.0.0',
#   'Android_Ver': '4.4 and up'},
#  {'App': 'Pyaterochka',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 3.1,
#   'Reviews': 8412,
#   'Size': nan,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '19-Jul-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': '4.4 and up'},
#  {'App': 'Refreshing app Free application that can use deal coupons',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 3.5,
#   'Reviews': 10741,
#   'Size': 41.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '23-Jul-18',
#   'Current Ver': '5.2.2',
#   'Android_Ver': '4.2 and up'},
#  {'App': 'Simple Recipes',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.7,
#   'Reviews': 3803,
#   'Size': 15.0,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '22-Feb-18',
#   'Current Ver': '1.6',
#   'Android_Ver': '4.0 and up'},
#  {'App': 'Grubhub: Food Delivery',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.5,
#   'Reviews': 155944,
#   'Size': 35.0,
#   'Installs': 5000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '2-Aug-18',
#   'Current Ver': '7.12',
#   'Android_Ver': '5.0 and up'},
#  {'App': 'Panera Bread',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.2,
#   'Reviews': 10159,
#   'Size': 36.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '17-Jul-18',
#   'Current Ver': '4.3.3',
#   'Android_Ver': '5.0 and up'},
#  {'App': 'Chick-fil-A',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.3,
#   'Reviews': 28008,
#   'Size': 17.0,
#   'Installs': 5000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '3-Aug-18',
#   'Current Ver': '6.0.1',
#   'Android_Ver': '5.0 and up'},
#  {'App': 'hellofood - Food Delivery',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.0,
#   'Reviews': 43614,
#   'Size': 25.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '12-Oct-16',
#   'Current Ver': '2.14.36',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Starbucks',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.5,
#   'Reviews': 455377,
#   'Size': 35.0,
#   'Installs': 10000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '1-Aug-18',
#   'Current Ver': '4.11.1',
#   'Android_Ver': '4.4 and up'},
#  {'App': 'Easy and quick desserts',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.6,
#   'Reviews': 1398,
#   'Size': 10.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone 10+',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '14-Jun-18',
#   'Current Ver': '1',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': "Domino's Pizza USA",
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.7,
#   'Reviews': 1032935,
#   'Size': nan,
#   'Installs': 10000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '20-Jul-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': 'Varies with device'},
#  {'App': 'Chef - Recipes & Cooking',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.1,
#   'Reviews': 32405,
#   'Size': 12.0,
#   'Installs': 5000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '3-Jul-18',
#   'Current Ver': '3.3.21',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Delivery Club-food delivery: pizza, sushi, burger, salad',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.3,
#   'Reviews': 151080,
#   'Size': nan,
#   'Installs': 5000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '27-Jul-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': 'Varies with device'},
#  {'App': 'HungerStation',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 3.8,
#   'Reviews': 22513,
#   'Size': 11.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '21-May-18',
#   'Current Ver': '5.3.8',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Delivery yogi.',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.4,
#   'Reviews': 90042,
#   'Size': nan,
#   'Installs': 10000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '18-Jul-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': 'Varies with device'},
#  {'App': 'Delivery trough - delivery trough delivery trough',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.3,
#   'Reviews': 58316,
#   'Size': nan,
#   'Installs': 5000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '25-Jul-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': 'Varies with device'},
#  {'App': 'Dr. Oetker recipe ideas',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.2,
#   'Reviews': 8509,
#   'Size': 17.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '12-Jul-18',
#   'Current Ver': '3.5.5',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'SONIC Drive-In',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.3,
#   'Reviews': 19314,
#   'Size': 43.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '31-Jul-18',
#   'Current Ver': '3.3.6',
#   'Android_Ver': '4.4 and up'},
#  {'App': 'SUBWAY®',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 3.8,
#   'Reviews': 21314,
#   'Size': 41.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '24-Jul-18',
#   'Current Ver': '7.9.0.0',
#   'Android_Ver': '4.4 and up'},
#  {'App': 'GialloZafferano: Recipes',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.3,
#   'Reviews': 30224,
#   'Size': nan,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '28-May-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': 'Varies with device'},
#  {'App': 'Dairy Queen',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 3.7,
#   'Reviews': 731,
#   'Size': 43.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '25-Jul-18',
#   'Current Ver': '2.1.0',
#   'Android_Ver': '4.1 and up'},
#  {'App': '9th stage',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.5,
#   'Reviews': 454,
#   'Size': 16.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '28-Mar-18',
#   'Current Ver': '2.0.0',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'OpenRice',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 3.6,
#   'Reviews': 14952,
#   'Size': 39.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '8-Jun-18',
#   'Current Ver': '5.8.5',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'SarashpazPapion (Cooking with Chef Bowls)',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.8,
#   'Reviews': 1250,
#   'Size': 13.0,
#   'Installs': 50000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '28-Jul-18',
#   'Current Ver': '3.2.7',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Little Caesars',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 3.3,
#   'Reviews': 1726,
#   'Size': 30.0,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '19-Jul-18',
#   'Current Ver': '4.26',
#   'Android_Ver': '4.4 and up'},
#  {'App': 'Recipes Pastries and homemade pies More than 500 recipes for pastries',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.7,
#   'Reviews': 14065,
#   'Size': 7.1,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '12-Jun-18',
#   'Current Ver': '1.2.2',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'Om Waleed Sweets',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.6,
#   'Reviews': 556,
#   'Size': 23.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Teen',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '25-Jan-18',
#   'Current Ver': '2',
#   'Android_Ver': '4.0 and up'},
#  {'App': 'Eat Fast Prepare "Without Internet"',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.6,
#   'Reviews': 4925,
#   'Size': 17.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '10-Jun-18',
#   'Current Ver': '3.6.6',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Wendy’s – Food and Offers',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 3.4,
#   'Reviews': 6507,
#   'Size': 18.0,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '12-Apr-18',
#   'Current Ver': '5.7.0',
#   'Android_Ver': '4.4 and up'},
#  {'App': 'My Recipes Cookbook : RecetteTek',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.6,
#   'Reviews': 11707,
#   'Size': nan,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '24-Jun-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': 'Varies with device'},
#  {'App': 'Healthy Recipes Free',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.0,
#   'Reviews': 1077,
#   'Size': 17.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '18-Oct-17',
#   'Current Ver': '3.2.0',
#   'Android_Ver': '4.0.3 and up'},
#  {'App': 'Cookbook Recipes',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.1,
#   'Reviews': 46539,
#   'Size': nan,
#   'Installs': 5000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Teen',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '23-Jul-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': 'Varies with device'},
#  {'App': 'ChefTap Recipes & Grocery List',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.5,
#   'Reviews': 9066,
#   'Size': 15.0,
#   'Installs': 500000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '25-Apr-18',
#   'Current Ver': '4.0.0.427',
#   'Android_Ver': '5.1 and up'},
#  {'App': 'Recipe Keeper',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.4,
#   'Reviews': 1962,
#   'Size': 22.0,
#   'Installs': 100000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '27-Jun-18',
#   'Current Ver': '3.17.1.0',
#   'Android_Ver': '4.1 and up'},
#  {'App': 'My CookBook (Recipe Manager)',
#   'Category': 'FOOD_AND_DRINK',
#   'Rating': 4.5,
#   'Reviews': 22071,
#   'Size': nan,
#   'Installs': 1000000,
#   'Type': 'Free',
#   'Price': 0.0,
#   'Content_Rating': 'Everyone',
#   'Genres': 'Food & Drink',
#   'Last_Updated': '29-Jun-18',
#   'Current Ver': 'Varies with device',
#   'Android_Ver': 'Varies with device'},
#  ...]

# %% [markdown]
# # Upload data to MongoDB

# %%
# Create connection variable
conn = 'mongodb://localhost:27017'

# Pass connection to the pymongo instance.
client = pymongo.MongoClient(conn)

# Connect to a database. Will create one if not already available.
db = client.android_apps

# %% [markdown]
# ### Create a collection for top 10 apps and upload dictionary

# %%
# Drops collection if available to remove duplicates
db.top_apps.drop()

# Creates a collection in the database and inserts two documents
db.all_apps.insert_many(data_dict)

# %% [markdown]
# ### Create a collection for all android apps and upload all records

# %%
# Drops collection if available to remove duplicates
db.all_apps.drop()

# Creates a collection in the database and inserts two documents
db.all_apps.insert_many(data_dict)

# %%
top10 = db.top_apps.find_one()

# %%
top10
# Out:
# {'_id': ObjectId('5cf2b30cc9a6711e9cf3d64e'),
#  'name': 'categories',
#  'children': [{'name': 'Art and design',
#    'children': [{'name': 'Textgram',
#      'installs': 10000000,
#      'rating': 4.4,
#      'reviews': 295221,
#      'price': 0.0},
#     {'name': 'ibis Paint X',
#      'installs': 10000000,
#      'rating': 4.6,
#      'reviews': 224399,
#      'price': 0.0},
#     {'name': 'FlipaClip',
#      'installs': 5000000,
#      'rating': 4.3,
#      'reviews': 194216,
#      'price': 0.0},
#     {'name': 'Canva: Poster, banner, card maker & graphic design',
#      'installs': 10000000,
#      'rating': 4.7,
#      'reviews': 174531,
#      'price': 0.0},
#     {'name': 'U Launcher Lite',
#      'installs': 5000000,
#      'rating': 4.7,
#      'reviews': 87510,
#      'price': 0.0},
#     {'name': 'Tattoo Name On My Photo Editor',
#      'installs': 10000000,
#      'rating': 4.2,
#      'reviews': 44829,
#      'price': 0.0},
#     {'name': 'Infinite Painter',
#      'installs': 1000000,
#      'rating': 4.1,
#      'reviews': 36815,
#      'price': 0.0},
#     {'name': 'Floor Plan Creator',
#      'installs': 5000000,
#      'rating': 4.1,
#      'reviews': 36639,
#      'price': 0.0},
#     {'name': 'Text on Photo',
#      'installs': 1000000,
#      'rating': 4.4,
#      'reviews': 13880,
#      'price': 0.0},
#     {'name': 'Sketch',
#      'installs': 50000000,
#      'rating': 4.5,
#      'reviews': 215644,
#      'price': 0.0}]},
#   {'name': 'Auto and vehicles',
#    'children': [{'name': 'Android Auto',
#      'installs': 10000000,
#      'rating': 4.2,
#      'reviews': 271920,
#      'price': 0.0},
#     {'name': 'Tickets + PDA 2018 Exam',
#      'installs': 1000000,
#      'rating': 4.9,
#      'reviews': 197136,
#      'price': 0.0},
#     {'name': 'AutoScout24',
#      'installs': 10000000,
#      'rating': 4.4,
#      'reviews': 186648,
#      'price': 0.0},
#     {'name': 'Fines of the State Traffic Safety Inspectorate are official: inspection, payment of fines',
#      'installs': 5000000,
#      'rating': 4.8,
#      'reviews': 116986,
#      'price': 0.0},
#     {'name': 'Fuelio: Gas log & costs',
#      'installs': 1000000,
#      'rating': 4.6,
#      'reviews': 65786,
#      'price': 0.0},
#     {'name': 'Used cars for sale',
#      'installs': 5000000,
#      'rating': 4.2,
#      'reviews': 52530,
#      'price': 0.0},
#     {'name': 'Ulysse Speedometer',
#      'installs': 5000000,
#      'rating': 4.3,
#      'reviews': 40211,
#      'price': 0.0},
#     {'name': 'ezETC (ETC balance inquiry, meter trial, real',
#      'installs': 1000000,
#      'rating': 4.3,
#      'reviews': 38846,
#      'price': 0.0},
#     {'name': 'auto fines',
#      'installs': 1000000,
#      'rating': 4.6,
#      'reviews': 31433,
#      'price': 0.0},
#     {'name': 'CarMax',
#      'installs': 1000000,
#      'rating': 4.4,
#      'reviews': 21777,
#      'price': 0.0}]},
#   {'name': 'Beauty',
#    'children': [{'name': 'ipsy: Makeup, Beauty, and Tips',
#      'installs': 1000000,
#      'rating': 4.9,
#      'reviews': 49790,
#      'price': 0.0},
#     {'name': 'Ulta Beauty',
#      'installs': 1000000,
#      'rating': 4.7,
#      'reviews': 42050,
#      'price': 0.0},
#     {'name': 'Mirror',
#      'installs': 1000000,
#      'rating': 3.9,
#      'reviews': 32090,
#      'price': 0.0},
#     {'name': 'Sephora: Skin Care, Beauty Makeup & Fragrance Shop',
#      'installs': 1000000,
#      'rating': 4.5,
#      'reviews': 26834,
#      'price': 0.0},
#     {'name': 'Selfie Camera',
#      'installs': 1000000,
#      'rating': 4.2,
#      'reviews': 17934,
#      'price': 0.0},
#     {'name': 'Mirror Camera (Mirror + Selfie Camera)',
#      'installs': 1000000,
#      'rating': 4.1,
#      'reviews': 9315,
#      'price': 0.0},
#     {'name': 'Filters for Selfie',
#      'installs': 1000000,
#      'rating': 4.3,
#      'reviews': 8572,
#      'price': 0.0},
#     {'name': 'Rainbow Camera',
#      'installs': 1000000,
#      'rating': 3.7,
#      'reviews': 3871,
#      'price': 0.0},
#     {'name': 'Beauty Camera',
#      'installs': 10000000,
#      'rating': 4.0,
#      'reviews': 113715,
#      'price': 0.0},
#     {'name': 'Best Hairstyles step by step',
#      'installs': 5000000,
#      'rating': 4.5,
#      'reviews': 45452,
#      'price': 0.0}]},
#   {'name': 'Books and reference',
#    'children': [{'name': 'Wattpad 📖 Free Books',
#      'installs': 100000000,
#      'rating': 4.6,
#      'reviews': 2914724,
#      'price': 0.0},
#     {'name': 'Bible',
#      'installs': 100000000,
#      'rating': 4.7,
#      'reviews': 2440695,
#      'price': 0.0},
#     {'name': 'JW Library',
#      'installs': 10000000,
#      'rating': 4.9,
#      'reviews': 922752,
#      'price': 0.0},
#     {'name': 'Dictionary.com: Find Definitions for English Words',
#      'installs': 10000000,
#      'rating': 4.6,
#      'reviews': 899010,
#      'price': 0.0},
#     {'name': 'Amazon Kindle',
#      'installs': 100000000,
#      'rating': 4.2,
#      'reviews': 814080,
#      'price': 0.0},
#     {'name': 'Wikipedia',
#      'installs': 10000000,
#      'rating': 4.4,
#      'reviews': 577550,
#      'price': 0.0},
#     {'name': 'Audiobooks from Audible',
#      'installs': 100000000,
#      'rating': 4.5,
#      'reviews': 568922,
#      'price': 0.0},
#     {'name': 'Quran for Android',
#      'installs': 10000000,
#      'rating': 4.7,
#      'reviews': 497826,
#      'price': 0.0},
#     {'name': 'Dictionary',
#      'installs': 10000000,
#      'rating': 4.5,
#      'reviews': 454060,
#      'price': 0.0},
#     {'name': 'Google Play Books',
#      'installs': 1000000000,
#      'rating': 3.9,
#      'reviews': 1433233,
#      'price': 0.0}]},
#   {'name': 'Business',
#    'children': [{'name': 'Facebook Pages Manager',
#      'installs': 50000000,
#      'rating': 4.0,
#      'reviews': 1279184,
#      'price': 0.0},
#     {'name': 'Uber Driver',
#      'installs': 10000000,
#      'rating': 4.4,
#      'reviews': 1254730,
#      'price': 0.0},
#     {'name': 'OfficeSuite : Free Office + PDF Editor',
#      'installs': 100000000,
#      'rating': 4.3,
#      'reviews': 1002861,
#      'price': 0.0},
#     {'name': 'Vault',
#      'installs': 50000000,
#      'rating': 4.5,
#      'reviews': 984451,
#      'price': 0.0},
#     {'name': 'File Commander',
#      'installs': 100000000,
#      'rating': 4.3,
#      'reviews': 758590,
#      'price': 0.0},
#     {'name': 'Indeed Job Search',
#      'installs': 50000000,
#      'rating': 4.3,
#      'reviews': 674730,
#      'price': 0.0},
#     {'name': 'MyASUS',
#      'installs': 10000000,
#      'rating': 4.4,
#      'reviews': 380837,
#      'price': 0.0},
#     {'name': 'Tiny Scanner',
#      'installs': 10000000,
#      'rating': 4.7,
#      'reviews': 286897,
#      'price': 0.0},
#     {'name': 'Docs To Go™ Free Office Suite',
#      'installs': 50000000,
#      'rating': 4.1,
#      'reviews': 217730,
#      'price': 0.0},
#     {'name': 'ES Task Manager (Task Killer )',
#      'installs': 10000000,
#      'rating': 4.3,
#      'reviews': 171771,
#      'price': 0.0}]},
#   {'name': 'Comics',
#    'children': [{'name': "Narrator's Voice",
#      'installs': 5000000,
#      'rating': 4.5,
#      'reviews': 564387,
#      'price': 0.0},
#     {'name': 'Manga Rock',
#      'installs': 1000000,
#      'rating': 4.4,
#      'reviews': 238970,
#      'price': 0.0},
#     {'name': 'comico Popular Original Cartoon Updated Everyday Comico',
#      'installs': 5000000,
#      'rating': 3.2,
#      'reviews': 93965,
#      'price': 0.0},
#     {'name': 'GANMA!',
#      'installs': 1000000,
#      'rating': 4.7,
#      'reviews': 57106,
#      'price': 0.0},
#     {'name': 'Perfect Viewer',
#      'installs': 5000000,
#      'rating': 4.4,
#      'reviews': 51981,
#      'price': 0.0},
#     {'name': 'Comics',
#      'installs': 5000000,
#      'rating': 4.1,
#      'reviews': 45651,
#      'price': 0.0},
#     {'name': 'WebComics',
#      'installs': 1000000,
#      'rating': 4.8,
#      'reviews': 33783,
#      'price': 0.0},
#     {'name': 'Tapas',
#      'installs': 1000000,
#      'rating': 4.5,
#      'reviews': 29839,
#      'price': 0.0},
#     {'name': 'Lezhin Comics',
#      'installs': 1000000,
#      'rating': 3.0,
#      'reviews': 28447,
#      'price': 0.0},
#     {'name': 'LINE WEBTOON',
#      'installs': 10000000,
#      'rating': 4.5,
#      'reviews': 1013635,
#      'price': 0.0}]},
#   {'name': 'Communication',
#    'children': [{'name': 'WhatsApp Messenger',
#      'installs': 1000000000,
#      'rating': 4.4,
#      'reviews': 69119316,
#      'price': 0.0},
#     {'name': 'Messenger',
#      'installs': 1000000000,
#      'rating': 4.0,
#      'reviews': 56642847,
#      'price': 0.0},
#     {'name': 'UC Browser',
#      'installs': 500000000,
#      'rating': 4.5,
#      'reviews': 17712922,
#      'price': 0.0},
#     {'name': 'Viber Messenger',
#      'installs': 500000000,
#      'rating': 4.3,
#      'reviews': 11334799,
#      'price': 0.0},
#     {'name': 'LINE: Free Calls & Messages',
#      'installs': 500000000,
#      'rating': 4.2,
#      'reviews': 10790289,
#      'price': 0.0},
#     {'name': 'Skype',
#      'installs': 1000000000,
#      'rating': 4.1,
#      'reviews': 10484169,
#      'price': 0.0},
#     {'name': 'Google Chrome: Fast & Secure',
#      'installs': 1000000000,
#      'rating': 4.3,
#      'reviews': 9642995,
#      'price': 0.0},
#     {'name': 'imo free video calls and chat',
#      'installs': 500000000,
#      'rating': 4.3,
#      'reviews': 4785892,
#      'price': 0.0},
#     {'name': 'Gmail',
#      'installs': 1000000000,
#      'rating': 4.3,
#      'reviews': 4604324,
#      'price': 0.0},
#     {'name': 'Hangouts',
#      'installs': 1000000000,
#      'rating': 4.0,
#      'reviews': 3419249,
#      'price': 0.0}]},
#   {'name': 'Dating',
#    'children': [{'name': 'Zoosk Dating App: Meet Singles',
#      'installs': 10000000,
#      'rating': 4.0,
#      'reviews': 516801,
#      'price': 0.0},
#     {'name': 'Moco',
#      'installs': 10000000,
#      'rating': 4.2,
#      'reviews': 313724,
#      'price': 0.0},
#     {'name': 'Hot or Not',
#      'installs': 10000000,
#      'rating': 4.1,
#      'reviews': 305708,
#      'price': 0.0},
#     {'name': 'OkCupid Dating',
#      'installs': 10000000,
#      'rating': 4.1,
#      'reviews': 285726,
#      'price': 0.0},
#     {'name': 'Hitwe',
#      'installs': 10000000,
#      'rating': 4.2,
#      'reviews': 243950,
#      'price': 0.0},
#     {'name': 'Find Real Love — YouLove Premium Dating',
#      'installs': 10000000,
#      'rating': 4.5,
#      'reviews': 212626,
#      'price': 0.0},
#     {'name': 'iPair',
#      'installs': 5000000,
#      'rating': 4.5,
#      'reviews': 182986,
#      'price': 0.0},
#     {'name': 'Free Dating App & Flirt Chat',
#      'installs': 5000000,
#      'rating': 4.4,
#      'reviews': 172460,
#      'price': 0.0},
#     {'name': 'Chat Rooms, Avatars, Date',
#      'installs': 10000000,
#      'rating': 4.3,
#      'reviews': 135418,
#      'price': 0.0},
#     {'name': 'Match™ Dating',
#      'installs': 10000000,
#      'rating': 3.7,
#      'reviews': 76646,
#      'price': 0.0}]},
#   {'name': 'Education',
#    'children': [{'name': 'Learn languages, grammar & vocabulary with Memrise',
#      'installs': 10000000,
#      'rating': 4.7,
#      'reviews': 1107903,
#      'price': 0.0},
#     {'name': 'Math Tricks',
#      'installs': 10000000,
#      'rating': 4.5,
#      'reviews': 342918,
#      'price': 0.0},
#     {'name': 'Learn English with Wlingua',
#      'installs': 10000000,
#      'rating': 4.7,
#      'reviews': 314299,
#      'price': 0.0},
#     {'name': 'Peak',
#      'installs': 10000000,
#      'rating': 4.4,
#      'reviews': 272145,
#      'price': 0.0},
#     {'name': 'Babbel',
#      'installs': 10000000,
#      'rating': 4.3,
#      'reviews': 266948,
#      'price': 0.0},
#     {'name': 'Lumosity: #1 Brain Games & Cognitive Training App',
#      'installs': 10000000,
#      'rating': 4.2,
#      'reviews': 215301,
#      'price': 0.0},
#     {'name': 'Quizlet: Learn Languages & Vocab with Flashcards',
#      'installs': 10000000,
#      'rating': 4.6,
#      'reviews': 211856,
#      'price': 0.0},
#     {'name': 'busuu: Learn Languages',
#      'installs': 10000000,
#      'rating': 4.3,
#      'reviews': 206527,
#      'price': 0.0},
#     {'name': 'Edmodo',
#      'installs': 10000000,
#      'rating': 4.1,
#      'reviews': 200058,
#      'price': 0.0},
#     {'name': 'Duolingo: Learn Languages Free',
#      'installs': 100000000,
#      'rating': 4.7,
#      'reviews': 6289924,
#      'price': 0.0}]},
#   {'name': 'Entertainment',
#    'children': [{'name': 'Netflix',
#      'installs': 100000000,
#      'rating': 4.4,
#      'reviews': 5456208,
#      'price': 0.0},
#     {'name': 'Hotstar',
#      'installs': 100000000,
#      'rating': 4.3,
#      'reviews': 4885646,
#      'price': 0.0},
#     {'name': 'Twitch: Livestream Multiplayer Games & Esports',
#      'installs': 50000000,
#      'rating': 4.6,
#      'reviews': 2133296,
#      'price': 0.0},
#     {'name': 'Talking Angela',
#      'installs': 100000000,
#      'rating': 3.7,
#      'reviews': 1828284,
#      'price': 0.0},
#     {'name': 'Talking Ben the Dog',
#      'installs': 100000000,
#      'rating': 4.3,
#      'reviews': 1633682,
#      'price': 0.0},
#     {'name': 'Talking Ginger 2',
#      'installs': 50000000,
#      'rating': 4.2,
#      'reviews': 702975,
#      'price': 0.0},
#     {'name': 'PlayStation App',
#      'installs': 50000000,
#      'rating': 4.2,
#      'reviews': 613059,
#      'price': 0.0},
#     {'name': 'IMDb Movies & TV',
#      'installs': 100000000,
#      'rating': 4.2,
#      'reviews': 501498,
#      'price': 0.0},
#     {'name': 'YouTube Kids',
#      'installs': 50000000,
#      'rating': 4.5,
#      'reviews': 470089,
#      'price': 0.0},
#     {'name': 'Google Play Games',
#      'installs': 1000000000,
#      'rating': 4.3,
#      'reviews': 7165362,
#      'price': 0.0}]},
#   {'name': 'Events',
#    'children': [{'name': 'Ticketmaster Event Tickets',
#      'installs': 5000000,
#      'rating': 4.0,
#      'reviews': 40113,
#      'price': 0.0},
#     {'name': 'StubHub',
#      'installs': 5000000,
#      'rating': 4.0,
#      'reviews': 26089,
#      'price': 0.0},
#     {'name': 'Fever',
#      'installs': 1000000,
#      'rating': 4.0,
#      'reviews': 20611,
#      'price': 0.0},
#     {'name': 'SeatGeek',
#      'installs': 1000000,
#      'rating': 4.4,
#      'reviews': 15558,
#      'price': 0.0},
#     {'name': 'Gametime',
#      'installs': 1000000,
#      'rating': 4.5,
#      'reviews': 8800,
#      'price': 0.0},
#     {'name': 'Vivid Seats',
#      'installs': 1000000,
#      'rating': 4.6,
#      'reviews': 8232,
#      'price': 0.0},
#     {'name': 'vide',
#      'installs': 100000,
#      'rating': 4.3,
#      'reviews': 5839,
#      'price': 0.0},
#     {'name': 'KudaGo',
#      'installs': 100000,
#      'rating': 4.4,
#      'reviews': 4298,
#      'price': 0.0},
#     {'name': 'LBB',
#      'installs': 100000,
#      'rating': 4.6,
#      'reviews': 3874,
#      'price': 0.0},
#     {'name': 'Reminder',
#      'installs': 500000,
#      'rating': 4.5,
#      'reviews': 7074,
#      'price': 0.0}]},
#   {'name': 'Family',
#    'children': [{'name': 'Hay Day',
#      'installs': 100000000,
#      'rating': 4.5,
#      'reviews': 10053186,
#      'price': 0.0},
#     {'name': 'Boom Beach',
#      'installs': 50000000,
#      'rating': 4.5,
#      'reviews': 5591653,
#      'price': 0.0},
#     {'name': 'Township',
#      'installs': 50000000,
#      'rating': 4.6,
#      'reviews': 4451317,
#      'price': 0.0},
#     {'name': 'SimCity BuildIt',
#      'installs': 50000000,
#      'rating': 4.5,
#      'reviews': 4218587,
#      'price': 0.0},
#     {'name': 'Talking Tom Cat 2',
#      'installs': 100000000,
#      'rating': 4.3,
#      'reviews': 3213548,
#      'price': 0.0},
#     {'name': 'Bubble Witch 2 Saga',
#      'installs': 100000000,
#      'rating': 4.3,
#      'reviews': 2838064,
#      'price': 0.0},
#     {'name': 'MARVEL Future Fight',
#      'installs': 50000000,
#      'rating': 4.6,
#      'reviews': 2354042,
#      'price': 0.0},
#     {'name': 'Bitmoji',
#      'installs': 100000000,
#      'rating': 4.6,
#      'reviews': 2312084,
#      'price': 0.0},
#     {'name': 'Clash of Kings : The King Of Fighters version',
#      'installs': 50000000,
#      'rating': 4.2,
#      'reviews': 2233681,
#      'price': 0.0},
#     {'name': 'Talking Tom Cat',
#      'installs': 100000000,
#      'rating': 4.3,
#      'reviews': 1838090,
#      'price': 0.0}]},
#   {'name': 'Finance',
#    'children': [{'name': 'Chase Mobile',
#      'installs': 10000000,
#      'rating': 4.6,
#      'reviews': 1374549,
#      'price': 0.0},
#     {'name': 'Bank of Brazil',
#      'installs': 10000000,
#      'rating': 4.5,
#      'reviews': 1336246,
#      'price': 0.0},
#     {'name': 'Itau bank',
#      'installs': 10000000,
#      'rating': 4.2,
#      'reviews': 957973,
#      'price': 0.0},
#     {'name': 'Credit Karma',
#      'installs': 10000000,
#      'rating': 4.7,
#      'reviews': 706301,
#      'price': 0.0},
#     {'name': 'Capital One® Mobile',
#      'installs': 10000000,
#      'rating': 4.6,
#      'reviews': 510392,
#      'price': 0.0},
#     {'name': 'İşCep',
#      'installs': 10000000,
#      'rating': 4.5,
#      'reviews': 381788,
#      'price': 0.0},
#     {'name': 'Bank of America Mobile Banking',
#      'installs': 10000000,
#      'rating': 4.4,
#      'reviews': 341090,
#      'price': 0.0},
#     {'name': 'CASHIER',
#      'installs': 10000000,
#      'rating': 3.3,
#      'reviews': 335738,
#      'price': 0.0},
#     {'name': 'Google Pay',
#      'installs': 100000000,
#      'rating': 4.2,
#      'reviews': 347838,
#      'price': 0.0},
#     {'name': 'PayPal',
#      'installs': 50000000,
#      'rating': 4.3,
#      'reviews': 659741,
#      'price': 0.0}]},
#   {'name': 'Food and drink',
#    'children': [{'name': "Domino's Pizza USA",
#      'installs': 10000000,
#      'rating': 4.7,
#      'reviews': 1032935,
#      'price': 0.0},
#     {'name': 'Tastely',
#      'installs': 10000000,
#      'rating': 4.7,
#      'reviews': 611136,
#      'price': 0.0},
#     {'name': 'Zomato',
#      'installs': 10000000,
#      'rating': 4.3,
#      'reviews': 511228,
#      'price': 0.0},
#     {'name': 'Foursquare City Guide',
#      'installs': 10000000,
#      'rating': 4.1,
#      'reviews': 483960,
#      'price': 0.0},
#     {'name': 'Starbucks',
#      'installs': 10000000,
#      'rating': 4.5,
#      'reviews': 455377,
#      'price': 0.0},
#     {'name': 'Uber Eats: Local Food Delivery',
#      'installs': 10000000,
#      'rating': 4.2,
#      'reviews': 333208,
#      'price': 0.0},
#     {'name': 'Pizza Hut',
#      'installs': 10000000,
#      'rating': 4.4,
#      'reviews': 321134,
#      'price': 0.0},
#     {'name': 'foodpanda',
#      'installs': 10000000,
#      'rating': 4.0,
#      'reviews': 292969,
#      'price': 0.0},
#     {'name': "McDonald's",
#      'installs': 10000000,
#      'rating': 3.6,
#      'reviews': 145323,
#      'price': 0.0},
#     {'name': 'Cookpad',
#      'installs': 10000000,
#      'rating': 4.5,
#      'reviews': 131569,
#      'price': 0.0}]},
#   {'name': 'Game',
#    'children': [{'name': 'Clash of Clans',
#      'installs': 100000000,
#      'rating': 4.6,
#      'reviews': 44891723,
#      'price': 0.0},
#     {'name': 'Clash Royale',
#      'installs': 100000000,
#      'rating': 4.6,
#      'reviews': 23133508,
#      'price': 0.0},
#     {'name': 'Candy Crush Saga',
#      'installs': 500000000,
#      'rating': 4.4,
#      'reviews': 22426677,
#      'price': 0.0},
#     {'name': 'My Talking Tom',
#      'installs': 500000000,
#      'rating': 4.5,
#      'reviews': 14891223,
#      'price': 0.0},
#     {'name': '8 Ball Pool',
#      'installs': 100000000,
#      'rating': 4.5,
#      'reviews': 14198297,
#      'price': 0.0},
#     {'name': 'Shadow Fight 2',
#      'installs': 100000000,
#      'rating': 4.6,
#      'reviews': 10979062,
#      'price': 0.0},
#     {'name': 'Pou',
#      'installs': 500000000,
#      'rating': 4.3,
#      'reviews': 10485308,
#      'price': 0.0},
#     {'name': 'Pokémon GO',
#      'installs': 100000000,
#      'rating': 4.1,
#      'reviews': 10424925,
#      'price': 0.0},
#     {'name': 'Minion Rush: Despicable Me Official Game',
#      'installs': 100000000,
#      'rating': 4.5,
#      'reviews': 10216538,
#      'price': 0.0},
#     {'name': 'Subway Surfers',
#      'installs': 1000000000,
#      'rating': 4.5,
#      'reviews': 27722264,
#      'price': 0.0}]},
#   {'name': 'Health and fitness',
#    'children': [{'name': 'Runtastic Running App & Mile Tracker',
#      'installs': 10000000,
#      'rating': 4.5,
#      'reviews': 827597,
#      'price': 0.0},
#     {'name': 'Nike+ Run Club',
#      'installs': 10000000,
#      'rating': 4.4,
#      'reviews': 708674,
#      'price': 0.0},
#     {'name': 'Period Tracker Clue: Period and Ovulation Tracker',
#      'installs': 10000000,
#      'rating': 4.8,
#      'reviews': 570242,
#      'price': 0.0},
#     {'name': 'Endomondo',
#      'installs': 10000000,
#      'rating': 4.5,
#      'reviews': 559186,
#      'price': 0.0},
#     {'name': 'Pedometer, Step Counter & Weight Loss Tracker App',
#      'installs': 10000000,
#      'rating': 4.6,
#      'reviews': 548021,
#      'price': 0.0},
#     {'name': 'Water Drink Reminder',
#      'installs': 10000000,
#      'rating': 4.6,
#      'reviews': 524299,
#      'price': 0.0},
#     {'name': 'Runkeeper',
#      'installs': 10000000,
#      'rating': 4.5,
#      'reviews': 501144,
#      'price': 0.0},
#     {'name': 'Samsung Health',
#      'installs': 500000000,
#      'rating': 4.3,
#      'reviews': 480208,
#      'price': 0.0},
#     {'name': 'Period Tracker',
#      'installs': 100000000,
#      'rating': 4.8,
#      'reviews': 4559407,
#      'price': 0.0},
#     {'name': 'Calorie Counter',
#      'installs': 50000000,
#      'rating': 4.6,
#      'reviews': 1873516,
#      'price': 0.0}]},
#   {'name': 'House and home',
#    'children': [{'name': 'Zillow: Find Houses for Sale & Apartments for Rent',
#      'installs': 10000000,
#      'rating': 4.5,
#      'reviews': 417907,
#      'price': 0.0},
#     {'name': 'Houzz Interior Design Ideas',
#      'installs': 10000000,
#      'rating': 4.6,
#      'reviews': 353799,
#      'price': 0.0},
#     {'name': 'Trulia Real Estate & Rentals',
#      'installs': 10000000,
#      'rating': 4.5,
#      'reviews': 175293,
#      'price': 0.0},
#     {'name': 'Realtor.com Real Estate: Homes for Sale and Rent',
#      'installs': 10000000,
#      'rating': 4.5,
#      'reviews': 162243,
#      'price': 0.0},
#     {'name': 'Alfred Home Security Camera',
#      'installs': 5000000,
#      'rating': 4.5,
#      'reviews': 103305,
#      'price': 0.0},
#     {'name': 'Trulia Rent Apartments & Homes',
#      'installs': 5000000,
#      'rating': 4.4,
#      'reviews': 71419,
#      'price': 0.0},
#     {'name': 'tinyCam Monitor FREE',
#      'installs': 10000000,
#      'rating': 4.0,
#      'reviews': 65914,
#      'price': 0.0},
#     {'name': 'Real Estate sale & rent Trovit',
#      'installs': 5000000,
#      'rating': 4.1,
#      'reviews': 65913,
#      'price': 0.0},
#     {'name': 'Room Creator Interior Design',
#      'installs': 1000000,
#      'rating': 3.9,
#      'reviews': 59660,
#      'price': 0.0},
#     {'name': 'Home Security Camera WardenCam',
#      'installs': 1000000,
#      'rating': 4.3,
#      'reviews': 43800,
#      'price': 0.0}]},
#   {'name': 'Libraries and demo',
#    'children': [{'name': 'MX Player Codec (ARMv7)',
#      'installs': 10000000,
#      'rating': 4.3,
#      'reviews': 332083,
#      'price': 0.0},
#     {'name': 'Cardboard',
#      'installs': 10000000,
#      'rating': 4.2,
#      'reviews': 130272,
#      'price': 0.0},
#     {'name': 'Aviary Stickers: Free Pack',
#      'installs': 10000000,
#      'rating': 3.5,
#      'reviews': 126862,
#      'price': 0.0},
#     {'name': 'Aviary Effects: Classic',
#      'installs': 5000000,
#      'rating': 3.8,
#      'reviews': 67007,
#      'price': 0.0},
#     {'name': 'Cool Popular Ringtones 2018 🔥',
#      'installs': 1000000,
#      'rating': 4.5,
#      'reviews': 60170,
#      'price': 0.0},
#     {'name': 'Wifi Connect Library',
#      'installs': 5000000,
#      'rating': 3.9,
#      'reviews': 58055,
#      'price': 0.0},
#     {'name': 'ES Chromecast plugin',
#      'installs': 1000000,
#      'rating': 4.2,
#      'reviews': 23859,
#      'price': 0.0},
#     {'name': 'OpenCV Manager',
#      'installs': 1000000,
#      'rating': 3.7,
#      'reviews': 12657,
#      'price': 0.0},
#     {'name': 'AZ Plugin 2 (newest)',
#      'installs': 1000000,
#      'rating': 4.2,
#      'reviews': 11087,
#      'price': 0.0},
#     {'name': 'Wifi Test',
#      'installs': 1000000,
#      'rating': 4.0,
#      'reviews': 8671,
#      'price': 0.0}]},
#   {'name': 'Lifestyle',
#    'children': [{'name': 'Muslim Pro',
#      'installs': 10000000,
#      'rating': 4.7,
#      'reviews': 1133393,
#      'price': 0.0},
#     {'name': 'happn',
#      'installs': 10000000,
#      'rating': 4.3,
#      'reviews': 1118201,
#      'price': 0.0},
#     {'name': 'Diary with lock',
#      'installs': 10000000,
#      'rating': 4.6,
#      'reviews': 815893,
#      'price': 0.0},
#     {'name': 'Family Locator',
#      'installs': 10000000,
#      'rating': 4.4,
#      'reviews': 726074,
#      'price': 0.0},
#     {'name': 'Daily Horoscope',
#      'installs': 10000000,
#      'rating': 4.7,
#      'reviews': 407589,
#      'price': 0.0},
#     {'name': 'iHoroscope',
#      'installs': 10000000,
#      'rating': 4.5,
#      'reviews': 398307,
#      'price': 0.0},
#     {'name': 'Mirror',
#      'installs': 1000000,
#      'rating': 3.9,
#      'reviews': 32090,
#      'price': 0.0},
#     {'name': 'Al',
#      'installs': 10000000,
#      'rating': 4.6,
#      'reviews': 284670,
#      'price': 0.0},
#     {'name': 'Tinder',
#      'installs': 100000000,
#      'rating': 4.0,
#      'reviews': 2789775,
#      'price': 0.0},
#     {'name': 'Samsung+',
#      'installs': 50000000,
#      'rating': 4.5,
#      'reviews': 82145,
#      'price': 0.0}]},
#   {'name': 'Maps and navigation',
#    'children': [{'name': 'Waze',
#      'installs': 100000000,
#      'rating': 4.6,
#      'reviews': 7232629,
#      'price': 0.0},
#     {'name': 'Uber',
#      'installs': 100000000,
#      'rating': 4.2,
#      'reviews': 4928420,
#      'price': 0.0},
#     {'name': 'GPS Navigation & Offline Maps Sygic',
#      'installs': 50000000,
#      'rating': 4.4,
#      'reviews': 1421884,
#      'price': 0.0},
#     {'name': 'Free GPS Navigation',
#      'installs': 50000000,
#      'rating': 4.2,
#      'reviews': 618562,
#      'price': 0.0},
#     {'name': 'Moovit: Bus Time & Train Time Live Info',
#      'installs': 10000000,
#      'rating': 4.4,
#      'reviews': 617477,
#      'price': 0.0},
#     {'name': 'Compass',
#      'installs': 10000000,
#      'rating': 4.3,
#      'reviews': 286454,
#      'price': 0.0},
#     {'name': 'Maps, GPS Navigation & Directions, Street View',
#      'installs': 10000000,
#      'rating': 4.2,
#      'reviews': 207440,
#      'price': 0.0},
#     {'name': 'TomTom GPS Navigation Traffic',
#      'installs': 10000000,
#      'rating': 4.1,
#      'reviews': 132792,
#      'price': 0.0},
#     {'name': 'Yandex.Transport',
#      'installs': 10000000,
#      'rating': 4.0,
#      'reviews': 126282,
#      'price': 0.0},
#     {'name': 'DB Navigator',
#      'installs': 10000000,
#      'rating': 4.0,
#      'reviews': 119685,
#      'price': 0.0}]},
#   {'name': 'Medical',
#    'children': [{'name': 'My Calendar',
#      'installs': 5000000,
#      'rating': 4.7,
#      'reviews': 156410,
#      'price': 0.0},
#     {'name': 'Ovia Pregnancy Tracker & Baby Countdown Calendar',
#      'installs': 1000000,
#      'rating': 4.8,
#      'reviews': 102858,
#      'price': 0.0},
#     {'name': 'Ada',
#      'installs': 1000000,
#      'rating': 4.7,
#      'reviews': 87418,
#      'price': 0.0},
#     {'name': 'Pregnancy Week By Week',
#      'installs': 1000000,
#      'rating': 4.8,
#      'reviews': 78825,
#      'price': 0.0},
#     {'name': 'FollowMyHealth®',
#      'installs': 1000000,
#      'rating': 4.6,
#      'reviews': 73118,
#      'price': 0.0},
#     {'name': 'Anatomy Learning',
#      'installs': 1000000,
#      'rating': 4.5,
#      'reviews': 72167,
#      'price': 0.0},
#     {'name': 'Pregnancy Calculator and Tracker app',
#      'installs': 1000000,
#      'rating': 4.8,
#      'reviews': 69126,
#      'price': 0.0},
#     {'name': 'GoodRx Drug Prices and Coupons',
#      'installs': 1000000,
#      'rating': 4.8,
#      'reviews': 59158,
#      'price': 0.0},
#     {'name': 'Ovia Fertility Tracker & Ovulation Calculator',
#      'installs': 1000000,
#      'rating': 4.8,
#      'reviews': 53743,
#      'price': 0.0},
#     {'name': 'Blood Pressure',
#      'installs': 5000000,
#      'rating': 4.2,
#      'reviews': 33033,
#      'price': 0.0}]},
#   {'name': 'News and magazines',
#    'children': [{'name': 'Twitter',
#      'installs': 500000000,
#      'rating': 4.3,
#      'reviews': 11667403,
#      'price': 0.0},
#     {'name': 'Flipboard: News For Our Time',
#      'installs': 500000000,
#      'rating': 4.4,
#      'reviews': 1284017,
#      'price': 0.0},
#     {'name': 'Reddit: Social News, Trending Memes & Funny Videos',
#      'installs': 10000000,
#      'rating': 4.6,
#      'reviews': 697212,
#      'price': 0.0},
#     {'name': 'News by The Times of India Newspaper',
#      'installs': 10000000,
#      'rating': 4.2,
#      'reviews': 522205,
#      'price': 0.0},
#     {'name': 'News Republic',
#      'installs': 10000000,
#      'rating': 4.3,
#      'reviews': 479594,
#      'price': 0.0},
#     {'name': 'Pulse Nabd',
#      'installs': 10000000,
#      'rating': 4.5,
#      'reviews': 357944,
#      'price': 0.0},
#     {'name': 'BaBe',
#      'installs': 10000000,
#      'rating': 4.3,
#      'reviews': 355921,
#      'price': 0.0},
#     {'name': 'BBC News',
#      'installs': 10000000,
#      'rating': 4.3,
#      'reviews': 296781,
#      'price': 0.0},
#     {'name': 'Google News',
#      'installs': 1000000000,
#      'rating': 3.9,
#      'reviews': 877635,
#      'price': 0.0},
#     {'name': 'Dailyhunt (Newshunt)',
#      'installs': 50000000,
#      'rating': 4.3,
#      'reviews': 948198,
#      'price': 0.0}]},
#   {'name': 'Parenting',
#    'children': [{'name': 'Feed Baby',
#      'installs': 1000000,
#      'rating': 4.5,
#      'reviews': 76795,
#      'price': 0.0},
#     {'name': 'Baby Sleep: White noise lullabies for newborns',
#      'installs': 1000000,
#      'rating': 4.6,
#      'reviews': 62386,
#      'price': 0.0},
#     {'name': 'Family Album Mitene: Private Photo & Video Sharing',
#      'installs': 1000000,
#      'rating': 4.7,
#      'reviews': 34336,
#      'price': 0.0},
#     {'name': 'Dormi',
#      'installs': 1000000,
#      'rating': 4.3,
#      'reviews': 11760,
#      'price': 0.0},
#     {'name': 'Safe365',
#      'installs': 1000000,
#      'rating': 4.4,
#      'reviews': 11501,
#      'price': 0.0},
#     {'name': 'My baby Phone',
#      'installs': 1000000,
#      'rating': 3.7,
#      'reviews': 9293,
#      'price': 0.0},
#     {'name': 'Baby Monitor',
#      'installs': 1000000,
#      'rating': 4.4,
#      'reviews': 5343,
#      'price': 0.0},
#     {'name': 'My baby firework',
#      'installs': 1000000,
#      'rating': 3.7,
#      'reviews': 4976,
#      'price': 0.0},
#     {'name': 'Pregnancy Tracker & Countdown to Baby Due Date',
#      'installs': 10000000,
#      'rating': 4.7,
#      'reviews': 658087,
#      'price': 0.0},
#     {'name': 'My baby Piano',
#      'installs': 5000000,
#      'rating': 3.9,
#      'reviews': 17941,
#      'price': 0.0}]},
#   {'name': 'Personalization',
#    'children': [{'name': 'GO Launcher',
#      'installs': 100000000,
#      'rating': 4.5,
#      'reviews': 7464996,
#      'price': 0.0},
#     {'name': 'CM Launcher 3D',
#      'installs': 100000000,
#      'rating': 4.6,
#      'reviews': 6702776,
#      'price': 0.0},
#     {'name': 'ZEDGE™ Ringtones & Wallpapers',
#      'installs': 100000000,
#      'rating': 4.6,
#      'reviews': 6466641,
#      'price': 0.0},
#     {'name': 'APUS Launcher',
#      'installs': 100000000,
#      'rating': 4.5,
#      'reviews': 5783441,
#      'price': 0.0},
#     {'name': 'Hola Launcher',
#      'installs': 100000000,
#      'rating': 4.5,
#      'reviews': 3277209,
#      'price': 0.0},
#     {'name': 'Parallel Space',
#      'installs': 100000000,
#      'rating': 4.6,
#      'reviews': 3062845,
#      'price': 0.0},
#     {'name': 'GO Keyboard',
#      'installs': 100000000,
#      'rating': 4.4,
#      'reviews': 2591941,
#      'price': 0.0},
#     {'name': 'Backgrounds HD (Wallpapers)',
#      'installs': 100000000,
#      'rating': 4.6,
#      'reviews': 2390185,
#      'price': 0.0},
#     {'name': 'Yandex Browser with Protect',
#      'installs': 50000000,
#      'rating': 4.5,
#      'reviews': 1237135,
#      'price': 0.0},
#     {'name': 'ZenUI Launcher',
#      'installs': 50000000,
#      'rating': 4.7,
#      'reviews': 1141545,
#      'price': 0.0}]},
#   {'name': 'Photography',
#    'children': [{'name': 'PicsArt Photo Studio: Collage Maker & Pic Editor',
#      'installs': 100000000,
#      'rating': 4.5,
#      'reviews': 7594559,
#      'price': 0.0},
#     {'name': 'PhotoGrid: Video & Pic Collage Maker, Photo Editor',
#      'installs': 100000000,
#      'rating': 4.6,
#      'reviews': 7529865,
#      'price': 0.0},
#     {'name': 'Retrica',
#      'installs': 100000000,
#      'rating': 4.3,
#      'reviews': 6120977,
#      'price': 0.0},
#     {'name': 'B612',
#      'installs': 100000000,
#      'rating': 4.4,
#      'reviews': 5282578,
#      'price': 0.0},
#     {'name': 'Camera360: Selfie Photo Editor with Funny Sticker',
#      'installs': 100000000,
#      'rating': 4.3,
#      'reviews': 4865093,
#      'price': 0.0},
#     {'name': 'Candy Camera',
#      'installs': 100000000,
#      'rating': 4.4,
#      'reviews': 3368649,
#      'price': 0.0},
#     {'name': 'YouCam Makeup',
#      'installs': 100000000,
#      'rating': 4.6,
#      'reviews': 3337956,
#      'price': 0.0},
#     {'name': 'BeautyPlus',
#      'installs': 100000000,
#      'rating': 4.4,
#      'reviews': 3158047,
#      'price': 0.0},
#     {'name': 'Cymera Camera',
#      'installs': 100000000,
#      'rating': 4.4,
#      'reviews': 2418135,
#      'price': 0.0},
#     {'name': 'Google Photos',
#      'installs': 1000000000,
#      'rating': 4.5,
#      'reviews': 10858556,
#      'price': 0.0}]},
#   {'name': 'Productivity',
#    'children': [{'name': 'ES File Explorer File Manager',
#      'installs': 100000000,
#      'rating': 4.6,
#      'reviews': 5383985,
#      'price': 0.0},
#     {'name': 'Microsoft Outlook',
#      'installs': 100000000,
#      'rating': 4.3,
#      'reviews': 3252896,
#      'price': 0.0},
#     {'name': 'Adobe Acrobat Reader',
#      'installs': 100000000,
#      'rating': 4.3,
#      'reviews': 3016297,
#      'price': 0.0},
#     {'name': 'SwiftKey Keyboard',
#      'installs': 100000000,
#      'rating': 4.5,
#      'reviews': 2764964,
#      'price': 0.0},
#     {'name': 'ColorNote Notepad Notes',
#      'installs': 100000000,
#      'rating': 4.6,
#      'reviews': 2401017,
#      'price': 0.0},
#     {'name': 'Microsoft Word',
#      'installs': 500000000,
#      'rating': 4.5,
#      'reviews': 2084126,
#      'price': 0.0},
#     {'name': 'Dropbox',
#      'installs': 500000000,
#      'rating': 4.4,
#      'reviews': 1861310,
#      'price': 0.0},
#     {'name': 'WPS Office',
#      'installs': 100000000,
#      'rating': 4.5,
#      'reviews': 1508137,
#      'price': 0.0},
#     {'name': 'CamScanner',
#      'installs': 100000000,
#      'rating': 4.6,
#      'reviews': 1502622,
#      'price': 0.0},
#     {'name': 'Google Drive',
#      'installs': 1000000000,
#      'rating': 4.4,
#      'reviews': 2731171,
#      'price': 0.0}]},
#   {'name': 'Shopping',
#    'children': [{'name': 'Wish',
#      'installs': 100000000,
#      'rating': 4.5,
#      'reviews': 6210998,
#      'price': 0.0},
#     {'name': 'Flipkart Online Shopping App',
#      'installs': 100000000,
#      'rating': 4.4,
#      'reviews': 6012719,
#      'price': 0.0},
#     {'name': 'AliExpress',
#      'installs': 100000000,
#      'rating': 4.6,
#      'reviews': 5916606,
#      'price': 0.0},
#     {'name': 'Mercado Libre: Find your favorite brands',
#      'installs': 50000000,
#      'rating': 4.7,
#      'reviews': 3860225,
#      'price': 0.0},
#     {'name': 'eBay: Buy & Sell this Summer',
#      'installs': 100000000,
#      'rating': 4.4,
#      'reviews': 2788923,
#      'price': 0.0},
#     {'name': 'Lazada',
#      'installs': 50000000,
#      'rating': 4.2,
#      'reviews': 1573054,
#      'price': 0.0},
#     {'name': 'Groupon',
#      'installs': 50000000,
#      'rating': 4.6,
#      'reviews': 1370749,
#      'price': 0.0},
#     {'name': 'Myntra Online Shopping App',
#      'installs': 50000000,
#      'rating': 4.3,
#      'reviews': 1315242,
#      'price': 0.0},
#     {'name': 'The birth',
#      'installs': 50000000,
#      'rating': 4.7,
#      'reviews': 1084945,
#      'price': 0.0},
#     {'name': 'letgo: Buy & Sell Used Stuff, Cars & Real Estate',
#      'installs': 50000000,
#      'rating': 4.5,
#      'reviews': 973270,
#      'price': 0.0}]},
#   {'name': 'Social',
#    'children': [{'name': 'Facebook',
#      'installs': 1000000000,
#      'rating': 4.1,
#      'reviews': 78158306,
#      'price': 0.0},
#     {'name': 'Instagram',
#      'installs': 1000000000,
#      'rating': 4.5,
#      'reviews': 66577313,
#      'price': 0.0},
#     {'name': 'Snapchat',
#      'installs': 500000000,
#      'rating': 4.0,
#      'reviews': 17014787,
#      'price': 0.0},
#     {'name': 'Facebook Lite',
#      'installs': 500000000,
#      'rating': 4.3,
#      'reviews': 8606259,
#      'price': 0.0},
#     {'name': 'VK',
#      'installs': 100000000,
#      'rating': 3.8,
#      'reviews': 5793284,
#      'price': 0.0},
#     {'name': 'Tik Tok',
#      'installs': 100000000,
#      'rating': 4.4,
#      'reviews': 5637451,
#      'price': 0.0},
#     {'name': 'Google+',
#      'installs': 1000000000,
#      'rating': 4.2,
#      'reviews': 4831125,
#      'price': 0.0},
#     {'name': 'Pinterest',
#      'installs': 100000000,
#      'rating': 4.6,
#      'reviews': 4305441,
#      'price': 0.0},
#     {'name': 'Tango',
#      'installs': 100000000,
#      'rating': 4.3,
#      'reviews': 3806669,
#      'price': 0.0},
#     {'name': 'Badoo',
#      'installs': 100000000,
#      'rating': 4.3,
#      'reviews': 3781770,
#      'price': 0.0}]},
#   {'name': 'Sports',
#    'children': [{'name': 'FIFA Soccer',
#      'installs': 100000000,
#      'rating': 4.2,
#      'reviews': 3909032,
#      'price': 0.0},
#     {'name': 'Top Eleven 2018',
#      'installs': 50000000,
#      'rating': 4.4,
#      'reviews': 3451011,
#      'price': 0.0},
#     {'name': 'EA SPORTS UFC®',
#      'installs': 50000000,
#      'rating': 4.5,
#      'reviews': 2371338,
#      'price': 0.0},
#     {'name': 'PES 2018 PRO EVOLUTION SOCCER',
#      'installs': 10000000,
#      'rating': 4.4,
#      'reviews': 1721943,
#      'price': 0.0},
#     {'name': 'NBA LIVE Mobile Basketball',
#      'installs': 50000000,
#      'rating': 4.4,
#      'reviews': 1690802,
#      'price': 0.0},
#     {'name': 'Real Basketball',
#      'installs': 10000000,
#      'rating': 4.5,
#      'reviews': 1605267,
#      'price': 0.0},
#     {'name': 'Online Soccer Manager (OSM)',
#      'installs': 10000000,
#      'rating': 4.5,
#      'reviews': 1312936,
#      'price': 0.0},
#     {'name': '3D Bowling',
#      'installs': 100000000,
#      'rating': 4.1,
#      'reviews': 1076243,
#      'price': 0.0},
#     {'name': '3D Tennis',
#      'installs': 50000000,
#      'rating': 4.2,
#      'reviews': 1008012,
#      'price': 0.0},
#     {'name': 'Wrestling Revolution 3D',
#      'installs': 50000000,
#      'rating': 4.3,
#      'reviews': 989344,
#      'price': 0.0}]},
#   {'name': 'Tools',
#    'children': [{'name': 'Clean Master',
#      'installs': 500000000,
#      'rating': 4.7,
#      'reviews': 42916526,
#      'price': 0.0},
#     {'name': 'Security Master',
#      'installs': 500000000,
#      'rating': 4.7,
#      'reviews': 24900999,
#      'price': 0.0},
#     {'name': '360 Security',
#      'installs': 100000000,
#      'rating': 4.6,
#      'reviews': 16771865,
#      'price': 0.0},
#     {'name': 'DU Battery Saver',
#      'installs': 100000000,
#      'rating': 4.5,
#      'reviews': 13479633,
#      'price': 0.0},
#     {'name': 'Cache Cleaner',
#      'installs': 100000000,
#      'rating': 4.5,
#      'reviews': 12759663,
#      'price': 0.0},
#     {'name': 'Battery Doctor',
#      'installs': 100000000,
#      'rating': 4.5,
#      'reviews': 8190074,
#      'price': 0.0},
#     {'name': 'SHAREit',
#      'installs': 500000000,
#      'rating': 4.6,
#      'reviews': 7790693,
#      'price': 0.0},
#     {'name': 'AVG AntiVirus 2018 for Android Security',
#      'installs': 100000000,
#      'rating': 4.5,
#      'reviews': 6207063,
#      'price': 0.0},
#     {'name': 'Google Translate',
#      'installs': 500000000,
#      'rating': 4.4,
#      'reviews': 5745093,
#      'price': 0.0},
#     {'name': 'Google',
#      'installs': 1000000000,
#      'rating': 4.4,
#      'reviews': 8033493,
#      'price': 0.0}]},
#   {'name': 'Travel and local',
#    'children': [{'name': 'Maps',
#      'installs': 1000000000,
#      'rating': 4.3,
#      'reviews': 9235155,
#      'price': 0.0},
#     {'name': 'Google Earth',
#      'installs': 100000000,
#      'rating': 4.3,
#      'reviews': 2338655,
#      'price': 0.0},
#     {'name': 'Google Street View',
#      'installs': 1000000000,
#      'rating': 4.2,
#      'reviews': 2129689,
#      'price': 0.0},
#     {'name': 'Booking.com Travel Deals',
#      'installs': 100000000,
#      'rating': 4.7,
#      'reviews': 1830388,
#      'price': 0.0},
#     {'name': 'TripAdvisor Hotels Flights Restaurants Attractions',
#      'installs': 100000000,
#      'rating': 4.4,
#      'reviews': 1162837,
#      'price': 0.0},
#     {'name': 'MAPS.ME',
#      'installs': 50000000,
#      'rating': 4.5,
#      'reviews': 932870,
#      'price': 0.0},
#     {'name': '2GIS: directory & navigator',
#      'installs': 50000000,
#      'rating': 4.5,
#      'reviews': 768833,
#      'price': 0.0},
#     {'name': 'GasBuddy: Find Cheap Gas',
#      'installs': 10000000,
#      'rating': 4.6,
#      'reviews': 751551,
#      'price': 0.0},
#     {'name': 'Where is my Train : Indian Railway & PNR Status',
#      'installs': 10000000,
#      'rating': 4.7,
#      'reviews': 620534,
#      'price': 0.0},
#     {'name': 'MakeMyTrip',
#      'installs': 10000000,
#      'rating': 4.3,
#      'reviews': 599872,
#      'price': 0.0}]},
#   {'name': 'Video players',
#    'children': [{'name': 'YouTube',
#      'installs': 1000000000,
#      'rating': 4.3,
#      'reviews': 25655305,
#      'price': 0.0},
#     {'name': 'VivaVideo',
#      'installs': 100000000,
#      'rating': 4.6,
#      'reviews': 9879473,
#      'price': 0.0},
#     {'name': 'VideoShow',
#      'installs': 100000000,
#      'rating': 4.6,
#      'reviews': 4016834,
#      'price': 0.0},
#     {'name': 'DU Recorder',
#      'installs': 50000000,
#      'rating': 4.8,
#      'reviews': 2588730,
#      'price': 0.0},
#     {'name': 'Dubsmash',
#      'installs': 100000000,
#      'rating': 4.2,
#      'reviews': 1971777,
#      'price': 0.0},
#     {'name': 'Vigo Video',
#      'installs': 50000000,
#      'rating': 4.3,
#      'reviews': 1615596,
#      'price': 0.0},
#     {'name': 'VLC for Android',
#      'installs': 100000000,
#      'rating': 4.4,
#      'reviews': 1032076,
#      'price': 0.0},
#     {'name': 'KineMaster',
#      'installs': 50000000,
#      'rating': 4.5,
#      'reviews': 1013867,
#      'price': 0.0},
#     {'name': 'LIKE',
#      'installs': 50000000,
#      'rating': 4.6,
#      'reviews': 921868,
#      'price': 0.0},
#     {'name': 'MX Player',
#      'installs': 500000000,
#      'rating': 4.5,
#      'reviews': 6474426,
#      'price': 0.0}]},
#   {'name': 'Weather',
#    'children': [{'name': 'Weather & Clock Widget for Android',
#      'installs': 50000000,
#      'rating': 4.4,
#      'reviews': 2371543,
#      'price': 0.0},
#     {'name': 'AccuWeather: Daily Forecast & Live Weather Reports',
#      'installs': 50000000,
#      'rating': 4.4,
#      'reviews': 2053404,
#      'price': 0.0},
#     {'name': 'The Weather Channel: Rain Forecast & Storm Alerts',
#      'installs': 50000000,
#      'rating': 4.4,
#      'reviews': 1558437,
#      'price': 0.0},
#     {'name': 'GO Weather',
#      'installs': 50000000,
#      'rating': 4.5,
#      'reviews': 1422858,
#      'price': 0.0},
#     {'name': 'Yahoo Weather',
#      'installs': 10000000,
#      'rating': 4.4,
#      'reviews': 1312037,
#      'price': 0.0},
#     {'name': 'Weather by WeatherBug: Forecast, Radar & Alerts',
#      'installs': 10000000,
#      'rating': 4.5,
#      'reviews': 981995,
#      'price': 0.0},
#     {'name': 'Yandex.Weather',
#      'installs': 10000000,
#      'rating': 4.5,
#      'reviews': 309617,
#      'price': 0.0},
#     {'name': 'Weather 14 Days',
#      'installs': 10000000,
#      'rating': 4.4,
#      'reviews': 279917,
#      'price': 0.0},
#     {'name': 'Amber Weather',
#      'installs': 10000000,
#      'rating': 4.4,
#      'reviews': 260137,
#      'price': 0.0},
#     {'name': 'wetter.com',
#      'installs': 10000000,
#      'rating': 4.2,
#      'reviews': 189313,
#      'price': 0.0}]}]}

# %%
apps = []
for document in db.all_apps.find():
    apps.append({k: v for k, v in document.items() if k !="_id"})
    
print(apps)
# Out:
# [{'App': 'Photo Editor & Candy Camera & Grid & ScrapBook', 'Category': 'ART_AND_DESIGN', 'Rating': 4.1, 'Reviews': 159, 'Size': 19.0, 'Installs': 10000, 'Type': 'Free', 'Price': 0.0, 'Content_Rating': 'Everyone', 'Genres': 'Art & Design', 'Last_Updated': '7-Jan-18', 'Current Ver': '1.0.0', 'Android_Ver': '4.0.3 and up'}, {'App': 'Coloring book moana', 'Category': 'ART_AND_DESIGN', 'Rating': 3.9, 'Reviews': 967, 'Size': 14.0, 'Installs': 500000, 'Type': 'Free', 'Price': 0.0, 'Content_Rating': 'Everyone', 'Genres': 'Art & Design;Pretend Play', 'Last_Updated': '15-Jan-18', 'Current Ver': '2.0.0', 'Android_Ver': '4.0.3 and up'}, {'App': 'U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'Category': 'ART_AND_DESIGN', 'Rating': 4.7, 'Reviews': 87510, 'Size': 8.7, 'Installs': 5000000, 'Type': 'Free', 'Price': 0.0, 'Content_Rating': 'Everyone', 'Genres': 'Art & Design', 'Last_Updated': '1-Aug-18', 'Current Ver': '1.2.4', 'Android_Ver': '4.0.3 and up'}, {'App': 'Sketch - Draw & Paint', 'Category': 'ART_AND_DESIGN', 'Rating': 4.5, 'Reviews': 215644, 'Size': 25.0, 'Installs': 50000000, 'Type': 'Free', 'Price': 0.0, 'Content_Rating': 'Teen', 'Genres': 'Art & Design', 'Last_Updated': '8-Jun-18', 'Current Ver': 'Varies with device', 'Android_Ver': '4.2 and up'}, {'App': 'Pixel Draw - Number Art Coloring Book', 'Category': 'ART_AND_DESIGN', 'Rating': 4.3, 'Reviews': 967, 'Size': 2.8, 'Installs': 100000, 'Type': 'Free', 'Price': 0.0, 'Content_Rating': 'Everyone', 'Genres': 'Art & Design;Creativity', 'Last_Updated': '20-Jun-18', 'Current Ver': '1.1', 'Android_Ver': '4.4 and up'}, {'App': 'Paper flowers instructions', 'Category': 'ART_AND_DESIGN', 'Rating': 4.4, 'Reviews': 167, 'Size': 5.6, 'Installs': 50000, 'Type': 'Free', 'Price': 0.0, 'Content_Rating': 'Everyone', 'Genres': 'Art & Design', 'Last_Updated': '26-Mar-17', 'Current Ver': '1', 'Android_Ver': '2.3 and up'}, {'App': 'Smoke Effect Photo Maker - Smoke Editor', 'Category': 'ART_AND_DESIGN', 'Rating': 3.8, 'Reviews': 178, 'Size': 19.0, 'Installs': 50000, 'Type': 'Free', 'Price': 0.0, 'Content_Rating': 'Everyone', 'Genres': 'Art & Design', 'Last_Updated': '26-Apr-18', 'Current Ver': '1.1', 'Android_Ver': '4.0.3 and up'}, {'App': 'Infinite Painter', 'Category': 'ART_AND_DESIGN', 'Rating': 4.1, 'Reviews': 36815, 'Size': 29.0, 'Installs': 1000000, 'Type': 'Free', 'Price': 0.0, 'Content_Rating': 'Everyone', 'Genres': 'Art & Design', 'Last_Updated': '14-Jun-18', 'Current Ver': '6.1.61.1', 'Android_Ver': '4.2 and up'}, {'App': 'Garden Coloring Book', 'Category': 'ART_AND_DESIGN', 'Rating': 4.4, 'Reviews': 13791, 'Size': 33.0, 'Installs': 1000000, 'Type': 'Free', 'Price': 0.0, 'Content_Rating': 'Everyone', 'Genres': 'Art & Design', 'Last_Updated': '20-Sep-17', 'Current Ver': '2.9.2', 'Android_Ver': '3.0 and up'}, {'App': 'Kids Paint Free - Drawing Fun', 'Category': 'ART_AND_DESIGN', 'Rating': 4.7, 'Reviews': 121, 'Size': 3.1, 'Installs': 10000, 'Type': 'Free', 'Price': 0.0, 'Content_Rating': 'Everyone', 'Genres': 'Art & Design;Creativity', 'Last_Updated': '3-Jul-18', 'Current Ver': '2.8', 'Android_Ver': '4.0.3 and up'}, {'App': 'Text on Photo - Fonteee', 'Category': 'ART_AND_DESIGN', 'Rating': 4.4, 'Reviews': 13880, 'Size': 28.0, 'Installs': 1000000, 'Type': 'Free', 'Price': 0.0, 'Content_Rating': 'Everyone', 'Genres': 'Art & Design', 'Last_Updated': '27-Oct-17', 'Current Ver': '1.0.4', 'Android_Ver': '4.1 and up'}, {'App': 'Name Art Photo Editor - Focus n Filters', 'Category': 'ART_AND_DESIGN', 'Rating': 4.4, 'Reviews': 8788, 'Size': 12.0, 'Installs': 1000000, 'Type': 'Free', 'Price': 0.0, 'Content_Rating': 'Everyone', 'Genres': 'Art & Design', 'Last_Updated': '31-Jul-18', 'Current Ver': '1.0.15', 'Android_Ver': '4.0 and up'}, {'App': 'Tattoo Name On My Photo Editor', 'Category': 'ART_AND_DESIGN', 'Rating': 4.2, 'Reviews': 44829, 'Size': 20.0, 'Installs': 10000000, 'Type': 'Free', 'Price': 0.0, 'Content_Rating': 'Teen', 'Genres': 'Art & Design', 'Last_Updated': '2-Apr-18', 'Current Ver': ' ...
