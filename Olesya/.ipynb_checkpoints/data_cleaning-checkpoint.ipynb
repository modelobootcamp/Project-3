# %%
import pandas as pd

# %%
rawdata_df = pd.read_csv("../data/googleplaystore.csv")

# %%
rawdata_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
data_df = rawdata_df.dropna()

# %%
data_df["Installs"] = data_df["Installs"].map(lambda x: int(x.strip("+").replace(',', '')))
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_df["Size"] = data_df["Size"].apply(lambda x: float(x.lower().strip('m'))*1000 
                                        if "m" in x.lower() 
                                        else (float(x.lower().strip('k')) if "k" in x.lower()
                                                    else x))
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
type(data_df['Size'][0])
# Out:
# float

# %%
data_df["Rating"] = data_df["Rating"].map(lambda x: float(x))
data_df["Price"] = data_df["Price"].map(lambda x: float(x.replace('$', '')))
data_df["Reviews"] = data_df["Reviews"].map(lambda x: int(x))
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data_cleaned = data_df.drop_duplicates(subset = 'App', inplace = True)
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Export = data_df.to_json ('db/data.json', orient = "records")

# %%
data_df.describe()
# Out:
#             Rating       Reviews      Installs        Price
# count  8190.000000  8.190000e+03  8.190000e+03  8190.000000
# mean      4.173321  2.554354e+05  9.171613e+06     1.038342
# std       0.536691  1.986309e+06  5.827170e+07    16.864040
# min       1.000000  1.000000e+00  1.000000e+00     0.000000
# 25%       4.000000  1.260000e+02  1.000000e+04     0.000000
# 50%       4.300000  3.009500e+03  1.000000e+05     0.000000
# 75%       4.500000  4.391425e+04  1.000000e+06     0.000000
# max       5.000000  7.815831e+07  1.000000e+09   400.000000

# %% [markdown]
# ### Create a pivot table for each category
#
# * Sum of downloads
# * Average downloads
# * Sum of reviews
# * Average reviews
# * Count of apps
# * Number of payed apps
# * Payed apps/free apps
# * Average price for payed apps
# *

# %% [markdown]
# ### Filter each category by top 10 apps by number of downloads
#
# * Each app: rating, downloads
# * Compare top payed apps and top free apps: number of downloads, ratings, number of reviews
# * Most downloaded vs most reviewd apps

# %%
# grouped = data_df.groupby('Category').apply(lambda x: x.sort_values(by = ["Installs", "Rating"], ascending=False))

grouped = data_df.groupby('Category').apply(lambda x: x.nlargest(10, ["Installs","Reviews","Rating"]))

# %%
grouped[grouped["Category"] == "DATING"]
# Out:
#                                                             App Category  \
# Category
# DATING   482                     Zoosk Dating App: Meet Singles   DATING
#          489                           Moco - Chat, Meet People   DATING
#          491                Hot or Not - Find someone right now   DATING
#          483                                     OkCupid Dating   DATING
#          591                       Hitwe - meet people and chat   DATING
#          502            Find Real Love — YouLove Premium Dating   DATING
#          600                           iPair-Meet, Chat, Dating   DATING
#          493  Free Dating App & Flirt Chat - Match with Singles   DATING
#          532                 Chat Rooms, Avatars, Date - Galaxy   DATING
#          484                       Match™ Dating - Meet Singles   DATING
#
#               Rating  Reviews                Size  Installs  Type  Price  \
# Category
# DATING   482     4.0   516801  Varies with device  10000000  Free    0.0
#          489     4.2   313724  Varies with device  10000000  Free    0.0
#          491     4.1   305708  Varies with device  10000000  Free    0.0
#          483     4.1   285726               15000  10000000  Free    0.0
#          591     4.2   243950               21000  10000000  Free    0.0
#          502     4.5   212626               11000  10000000  Free    0.0
#          600     4.5   182986               77000   5000000  Free    0.0
#          493     4.4   172460                3100   5000000  Free    0.0
#          532     4.3   135418  Varies with device  10000000  Free    0.0
#          484     3.7    76646  Varies with device  10000000  Free    0.0
#
#              Content Rating  Genres    Last Updated         Current Ver  \
# Category
# DATING   482     Mature 17+  Dating  August 2, 2018  Varies with device
#          489     Mature 17+  Dating  August 4, 2018             2.6.141
#          491     Mature 17+  Dating  August 2, 2018  Varies with device
#          483     Mature 17+  Dating   July 30, 2018             11.10.1
#          591     Mature 17+  Dating    May 10, 2018               4.3.2
#          502     Mature 17+  Dating   July 31, 2018              4.17.2
#          600     Mature 17+  Dating  August 2, 2018               5.0.8
#          493     Mature 17+  Dating  August 4, 2018               1.639
#          532     Mature 17+  Dating    July 7, 2018  Varies with device
#          484     Mature 17+  Dating   July 23, 2018  Varies with device
#
#                      Android Ver
# Category
# DATING   482  Varies with device
#          489          4.1 and up
#          491  Varies with device
#          483          4.1 and up
#          591          4.1 and up
#          502          4.1 and up
#          600          4.1 and up
#          493          4.0 and up
#          532  Varies with device
#          484  Varies with device

# %%
new_dict = {"name": "categories",
            "children": [{"name": k, "children": [{"name":app, "value":int(grouped[grouped['App']==app]['Installs'])} 
                                          for app in grouped[grouped['Category'] == k]['App']]} 
                          for k in grouped.index.levels[0]]}

# %%
import json

with open('db/top_apps.json', 'w') as fp:
    json.dump(new_dict, fp)
